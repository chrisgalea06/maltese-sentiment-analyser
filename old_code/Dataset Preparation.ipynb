# %% [markdown]
# ## Importing required libraries

# %%
# Import pandas
import pandas as pd
import os
import re
import langid
import string
import numpy
import fitz 
import nltk
import json
import requests
from Levenshtein import distance

# %% [markdown]
# ## Helper Functions

# %%
def has_numbers(inputString):
    return bool(re.search(r'\d', inputString))

# %%
def clean_list(list):
    new_list = []
    for word in list:
        new_word = clean_word(word)
        new_list.append(new_word)
    return new_list

# %%
def clean_word(word):
    word = re.sub(r'[^\w\s]', '', word)
    word = word.lower()
    
    return word

# %%
WORD = re.compile(r'\w+')
def tokenize(text):
    words = WORD.findall(text)
    return words

# %%
def check_list(list,word):
    if word in list:
        return True
    else:
        return False

# %%
# https://stackoverflow.com/a/49146722/330558
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %% [markdown]
# ## Importing different csv files containing comments

# %%
filenames = next(os.walk('Comments/'), (None, None, []))[2]  # [] if no file
filenames
# Out:
# ['cospicua_primary_comments.csv',
#  'gwida_comments.csv',
#  'ira_losco_comments.csv',
#  'kelmakelma_comments.csv',
#  'liqourish_comments.csv',
#  'malta_dizastru_totali_comments.csv',
#  'malta_traffic_comments.csv',
#  'malti_madwarna_comments.csv',
#  'newsbook_comments.csv',
#  'one_chick_and_a_yorkie_comments.csv',
#  'peristyle_comments.csv',
#  'replay_comments.csv',
#  'ricetti_maltin_comments.csv',
#  'tvm_comments.csv',
#  'xfactor_comments.csv']

# %%
dataframes = []
for f in filenames:
    df = pd.read_csv("Comments/"+f)
    df = df['message']
    dataframes.append(df)

# %%
len(dataframes)
# Out:
# 15

# %% [markdown]
# ## Appending each dataframe into one list

# %%
raw_comments = []
for df in dataframes:
    temp_comments = df.to_numpy().tolist()
    if raw_comments:
        raw_comments.extend(temp_comments)
    else:
        raw_comments = temp_comments

# %%
len(raw_comments)
# Out:
# 119572

# %% [markdown]
# ## Ensuring that each comment is not longer than 1 sentence

# %%
list_of_comments = []
for comment in raw_comments:
    comment = str(comment).strip()
    a_list = nltk.tokenize.sent_tokenize(comment)
    if list_of_comments:
        list_of_comments.extend(a_list)
    else:
        list_of_comments = a_list

# %%
len(list_of_comments)
# Out:
# 149867

# %%
#list_of_comments = list_of_comments[0:20000]

# %% [markdown]
# ## Cleaning the list of comments

# %%
words_to_remove = ['nan','Goodluck','Good luck','Good Luck','GoodLuck','Welldone', 'Well done','RIP','rip','proud'
                   ,'Proud','well','done','Rip','Bravu','proset','Bravi','Brava','God','Grazzi','Thank']
words_re = re.compile("|".join(words_to_remove))

cleaned_comments = []
for c in list_of_comments:
    
    c = str(c).strip()
    if words_re.search(c):        
        continue
    else:
        c = remove_emoji(c)
        cleaned_comments.append(c)

# %%
len(cleaned_comments)
# Out:
# 121008

# %%
cleaned_comments
# Out:
# ['bravu lyon',
#  'THANKS FOR YOUR APPRECIATION.....',
#  "RevCan Emmanuel Schembri grazzi lilek Father, ta' kemm tiehu hsiebna!",
#  'Prosit ms falzon ezempju car ta kif tmexxi skola b determinazjoni u hegga.grazzi talli dejjem kont hemm biex tisma l kulhadd.jien hdimt mieghek zmien ilu u vera mara kif jejdu tal genn prosit',
#  'Nixtieq nirringrazzja lil Mr Pulis u lil Ms Mallia  ( Year 5) tal hidma kontinwa li taw lit tfal taghna .',
#  'Ser nimmisjawkom u nispera li nergu niltaqu lura jekk il bambin irid ma ndumux .',
#  'Sahha lil kullhadd .',
#  'grazzi ta kollox lil kullhadd ',
#  'Ha nimisawkim hafna u anke tfal zgur li nigu nitawlulkhom .',
#  'Fismi u fisem shabi nejdulkom grazzi tal hsieb , ghax ghal kemm ahna ckejknin imma ma gejnix minsijin ',
#  'George Vella',
#  'Carol Grech ',
#  'Prosit !',
#  '!',
#  'Verygood',
#  'bravu sabih',
#  'My boy',
#  'Rachel Brignoli',
#  'Kif nista namel bix naplika pls tiji qat ma kinu imoru bil van',
#  'Bernice Bellotti hemm post ohra ghal min ha japplika l-ewwel darba',
#  'SMC Cospicua Primary  thanks',
#  'My boy',
#  'Proset',
#  'Paula Picina Mallia',
#  'uliedi u tfal ta ibni kollha morna f din l skola',
#  'Fej aw',
#  'Paula Picina Mallia liskola primaria ta bormla',
#  'Istra',
#  'Istra kif kienet',
#  "This is the video that was the inspiration for Ms Mugliett's lesson: https://www.facebook.com/watch/?v=271636080664824&external_log_id=08f97d933fbf32715757bcd1104c2392&q=cook%20wow%20garlic%20bread",
#  '',
#  'good job ',
#  'Prosit Elljay x',
#  'Yummy yummy in your tummy',
#  'From keziah x x',
#  'Proset sabiha ',
#  'Kemm huma bravi 🥰',
#  'Kemm ghandna tfal bravi xxxxxxxxx',
#  'Kemm ilek ma tghajjatli Maria, Gilston!',
#  'Proset tfal kemm Intom bravi ',
#  'Prosit tassew !',
#  'Proset pupa',
#  'bravi ',
#  '',
#  'Proset',
#  'Hanini Emma xx',
#  'Ajma xi hlew xxxxx brava Emma',
#  'Xi hlew Emma  🥰',
#  'Kemm hi helwa xx',
#  'Prosit pupa!',
#  'Xxx',
#  'Krystle Callus xxxx Keep on shining little star ',
#  'Raisa Brincat thankyou  xxxx',
#  'Prosit u grazzi',
#  'Proset lil ghalliema u  grazzi',
#  'Kemm ghandna tfal, genituri u ghalliema bravi!',
#  'Kemm hu bravu  Zyon',
#  'bravu sabih',
#  'Kemm hemm tfal bravi l-iskola ta’ Bormla!',
#  'Keep it up pupi',
#  'Frances Zammit hafna!',
#  'Qalilkom chylon thank you u nixtiqu nirringrazzjaw li sir pulis tal pacenzja li qed jihu bijna u jispjegalna kollox fid dettal kif ukoll lil miss maronia ukoll grazzi ta kull ma qedijn tghamlu ma tfal taghna ',
#  '!',
#  'king',
#  'Kemm ghandna tfal, ommijiet u ghalliema bravi!',
#  'xi hleww kolla bravii <3',
#  'Kemm ghandna tfal bravi',
#  'Proset Ms Stephanie Farrugia xx',
#  'Prosit ghax bil ghajnuna taghkom qed ikomplu jitghalmu grazzi',
#  'Proset li teachers li hawn go liskola taghna!',
#  'Jien kburija bikom ghal dejjem.',
#  "Granet jahdmu b'tant dedikazjoni liema bhala.",
#  ' Ms Falzon grazzi talli go liskola taghna igibilna teachers li lebda virus, lebda marda u lebda hadd ma qatalhom qalbom ghax mhux talli et jghalmu it tfal issa et jghalmu lilna ukoll ',
#  'Charlene Grixti kemm inti helwa!',
#  'It-teachers mhux jien ingibhom!',
#  "Jiena kap ta' skola ixxurtjata ghax inzerta ghandi l-aqwa u l-ahjar!",
#  'U anke intom il-genituri, il-maggoranza sibna koperazzjoni kbira minn ghandkom!',
#  'Proset Ms.Falzon .',
#  'Veronica Chircop l aqwa l patata kbira :)',
#  '!',
#  'Kemm hi gustuza Alla jberikha xxx',
#  'Yes Emma !!!!',
#  '!',
#  'kemm hi helwa :) xx',
#  'bravu zayon ',
#  'Prosit!',
#  'Kburin bikom',
#  'the best xx',
#  'Enya waqt lura miskina habba it tablet',
#  'Joyce Aquilina Bartolo bghattlek messagg inbox',
#  'Proset u ty xx',
#  'Prosit lil kulhadd u grazzi lill-ghalliema dedikati li ghandna!',
#  'Proset u grazzi xx',
#  '',
#  'Xxx bravi',
#  'Hanini kem int bravu',
#  'Xxxxxxxxx grazzi hafna laktar hin prezjuz Huwa linqatta hini mahom xxxxx ax malajr  jikbru',
#  'bravu sabih ',
#  'Kemm  hu  bravu  zyon',
#  'Kemm inti bravu!',
#  'YESSS            BRAVI INHOBBUKOM',
#  'Kemm intom helwin xx',
#  'Kemm intom helwinnnnn miss you all 🥰',
#  'Xi hlew kem intom helwin GRAZZI u nhobbukom 🥰',
#  'Kemm inkom  helwinnnn miss you all  u grazzi u nhobbukom',
#  'Pauline Ghio il-madam kellha hafna hegga biex taghmlu imbaghad sthat taghmlu!',
#  'Mhux is-soltu tisthi!',
#  "Issa nipruvaw f'iehor!",
#  'SMC SMC Cospicua Primary ha nkun qeghda nistennih bil herqa 🤸\u200d Cospicua Primary',
#  '<3 <3 <3  braviiiii',
#  'Proset bravi',
#  'Same to you all xxx',
#  'same to you',
#  'Same to you all',
#  'Same to you all',
#  'Same to you all',
#  'same  to you all',
#  'bravu zayon ',
#  'Keep it up ',
#  'jien ircivet mesag ima ma etulix meta u hij pls',
#  "Yanika Gilford 14 ta'Mejju",
#  'Kemm uma bravi dawn tfal ',
#  'Keep up your brilliant work ',
#  'Kemm uma bravi xxxxx wisq kburija  bikom love you  bambini tijaj',
#  '!',
#  '',
#  'Proset u grazzi',
#  'Mela priministru amel skoss mizuri floppinjoni tijji tajbin , pero il mizura li ta lili kinet li fil workshop tefali iswed u mignuna .',
#  'Kif tridni niftijem mahhom dawn prim ?',
#  '',
#  'Johnny Schembri Bigillu qisu ha over il gdid .',
#  'Qisu l foreman qed narah jien !',
#  '!',
#  'Màrìçà Brìncat Vàssallo mux ha nejt li qet imexxi hazin , imma fil kas tijji iva ',
#  'Johnny Schembri Bigillu mela veru l foreman dak?',
#  'Màrìçà Brìncat Vàssallo jien ghal prim qet niteferi ta !',
#  'Johnny Schembri Bigillu lol u jien ghal dak il gdid li hemm maghkhom ibajjad',
#  'Li int qed tghid mhux tifhmu',
#  'Màrìçà Brìncat Vàssallo ooooooo gesuuuuu mela vera qet tipruvaw tehilsu minni bil pulit hat mu jifimni ',
#  'Johnny Schembri Bigillu le x nehilsu minnek hi ahna nhobbuk .',
#  'Keep up the good work!',
#  '🤩',
#  '!',
#  'Tks Miss marie',
#  'Kemm hi sabiha prosit ',
#  'keep it up !',
#  'will send more work soon',
#  'Kemm Inti  bravu  xxx xtikbirli',
#  'Same to you all xxx.',
#  'Ser nimmisjaha dis sena li gibli Faith mil iskola tal mothers day.',
#  '!',
#  'Same to all of you and thanks for all you do ',
#  'Same to you all',
#  'Same to you all',
#  'Ajma kemm inthom helwin ',
#  'xxxxx',
#  'Such a nice thought ',
#  'Prosit!',
#  '',
#  'Teachers',
#  '',
#  'Prosit, kemm hadt pjacir narakom xxx',
#  'Iiiii dawn min huma qisni nafom ximkien.',
#  'Hahajjj.',
#  'Miss you ',
#  '',
#  'Miss you all x',
#  'Prosit Mariah ',
#  'Prosit Mariah ',
#  'Xx',
#  'I loved the story, thanks for reading it.',
#  'Salve Mattia!',
#  'Come stai?',
#  'Bene, grazie!',
#  'Sto facendo il fratello maggiore.',
#  'tks',
#  '?',
#  'thanks',
#  'Kimberlyn Decelis iva',
#  'thank you',
#  'Tks',
#  'What do we need to bring ?',
#  'As if I read properly in maltese we have to bring something with us ?',
#  'In English there is nothing stated',
#  "Tracy Gatt you're right!",
#  'Bring a pen with you as we cannot share.',
#  'You need to sign.',
#  'SMC Cospicua Primary ok thank you xxx',
#  'Prosit Ms Maria tal-lezzjonijiet sbieh!',
#  'Kemm ghandna tfal bravi hux?',
#  'SMC Cospicua Primary hafna wkoll!!',
#  'Niehu gost nara x xoghol taghhom!',
#  'Sodisfazzjon kbir xx',
#  'Kemm hi brava Kenzy!!',
#  'Ma kellix dubju li ser tipruva!',
#  'Dejjem kienet tkun looking forward ghall klassi tieghi u toqghod attenta!',
#  'Prosit, Ms Maria kemm taghmlilhom affarijiet sbieh!',
#  'Din aneshia Micallef miss falzon',
#  'I still dont understand them looooll ',
#  'Tracy Gatt ejja kuragg  you can do it Trac ',
#  'Tracy Buckland my kids faces say it all ...ma ..what u trying to say looooolll',
#  'Alison Lautier ty miss lautier xxx',
#  'Tracy Gatt ooooo poor Tracy ',
#  'Tracy Gatt miss you all xx',
#  'Alison Lautier I think I can speak for all the kids especially paige misses u too :( considering tgey were sick before didnt really say good bye properly xx',
#  'Tracy Gatt I know :( it s a heartache that we didn t get to finish this scholastic year together.',
#  'It was a pleasure having them in my class.',
#  'Big hugs to all x',
#  '',
#  'brava qalbi ',
#  'From Zolaya& zylon',
#  'Tku from zolaya',
#  'Wow bravu Gabriel x. Kemm tidher tajba ',
#  "F'Kollox ihobb jghin Gabriel.",
#  'Prosit Sur Pulis u prosit Elias!',
#  '',
#  'Maronia Mallia ghandek ragun!',
#  'Elias ghand is-Sur Pulis kien!',
#  'Niskuza ruhi Sur Pulis!',
#  'Hahahahha mela ghalxejn ha jirrapurtani  fuq abbuz fuq it-tfal ghax il-head ukol taqbel mieghi ',
#  '!',
#  'Maruska keep up the good work ',
#  'Nicholas says hello long time no see to Elias xx',
#  'Miss you sooo muchhh  all of you ',
#  'Ghara fejnu sabih tana .gmillll kemm inhobu jien xxxxxxxxx',
#  'Xi hlew',
#  'Xi hleww ta pupu god bless',
#  'Kemm hi interessanti ms falzon din I love it!',
#  'Kayden Seisun Spiteri bongu!',
#  'You love it dear?',
#  'Daq l-aqwa!',
#  'Dak ifisser li inti bravu u qed tahdem!',
#  'R.I.P.',
#  'R.I.P.',
#  'Amen ',
#  'R.I.P',
#  'R.ip',
#  'Strieh fis sliem habieb taghna',
#  'R. I. P.',
#  'Prosit Kelsey',
#  'Awguri',
#  'Awguri ',
#  'Awguri',
#  'Awguri',
#  'Very happy for you',
#  'Awguri',
#  'MY GODNESS IMWERWRA NKUN META JOQROB IL LEJL GHAX ZEJTUN IN NAHA TAGHNA KWAZI KULJUM',
#  'Prosit kbira',
#  'Bravo, you are a hero and many others who are donors like you, there are no words  enough to express our hearthful thanks',
#  'Proset',
#  'Proset',
#  '!',
#  'Xx',
#  'Proset',
#  'MARIO.',
#  'Proset.',
#  'Xi gmiel ta gest!!!',
#  '!',
#  'Ma tapplikax jekk tkun tgh8x fl istess saqaf!',
#  'Ritianne Abela ovja  Ghax xorta tista’ tigi nfettat  Common sense hux',
#  'Mela mghadux.jista jghatih il hadihor u jdum 14 il.gurnata... saru jbelhuni dawn li special offers',
#  'dahq fil wicc tuna hajitna lura',
#  "U ejaaaaaaa bi serjeta ha tgenuni man I'ma dawn jafu xinhom jaghmlu .U jien ma kenli qat contact ma xi had bill covid U nziilt bil PCR test U jidulk trid taghmil kwarantina hotel mux Dar tieghk avorija bi certificate ukol U full vaccine.leeeeee hi xein sew .",
#  'Raya Ran pcr test negative?',
#  'Antoinette Gordon Formosa Mela hi kolox sew kenli U kul had jfarfar U had ma jmeti Li din bixxa xol hi zbal kbir.',
#  'Raya Ran  ajma..hazin.imma ala tefawk kwaratina ax ma nistax nifem?',
#  'Antoinette Gordon Formosa qas jien qalbi Emini ha nigenin hi had mu at jidli ghala xbajna nitklmu ghal xein .kolox sew kelna I promess.',
#  'Good News.',
#  '14 days was too long for contacts.',
#  'Emanuel Seguna hlief bullshit ma jghidux, qatt ma jghamel sens kliemhom,u min hu gahan jghidlu grazzi ministru ghal paprati li qed jghid..... ahjar ma jqazzizx iktar l angli bil qrid tal vaccine forsi jghamel naqra gid',
#  'Covid19 kixef il kabacita ta koll hadt Dak li naf',
#  'Josephine Zerafa thawad ... ahjar nintefa naqta l.bajtar',
#  'Emanuel Seguna sew qed tghid illum jghidu hekk u l ghada jghidu modiehor',
#  'Discounted quarantine',
#  'PROSET MINISTRU U IL FRONT LINERS.',
#  '86% ta l-adulti mhux tall-popolazzjoni hi.',
#  'Mela xiz zo** qed tistennew biex tifthu??',
#  '?',
#  'Prosit grazzi ta kollox',
#  'Proset hafna  Ministru u t team tieghi u l front liners !',
#  'Proset',
#  'Proset u Grszzi',
#  'Proset Ministru u il Front Liners',
#  'Prosit u thanks ta kollox',
#  "Fadal 14% x'jittlaqqmu",
#  'What are they waiting for?',
#  'Prosit hafna tal hidma tieghek min ghajr waqfien ',
#  'Minn jista jghin',
#  'Pls.',
#  'NO mass events during a pandemic.',
#  'It is stupid, we already have lots of covid cases daily',
#  'Issa naraw x inhu gej min dawn incredibli',
#  'Probably about the booster',
#  'Li ha jerga jinqata id dawl 🤣🤣',
#  'Imma kemm hawn nies negativi incredibli ninflokk ma nirringrazjaw l alla u lil dawn in nies',
#  'Jien nahseb fuq il booster',
#  'Ejja sa jnehu l bastiment ha jinvestu f x haga iktar moderna daqshekk qtuh tad dawl YIPPIEE',
#  'DAN KIF MHUX SEJTIJA FUQ TVM',
#  'Bongu good bless you two',
#  'Hopefully li se tonqos il kwarantina ghal dawk li huma vvaccinati.',
#  'Li lukaku al ma chelsea ',
#  'Kunu positivi iderw il bija irridu nejxu',
#  'Ma nafx x hemm tad dahk',
#  'Jek ikun hemm kontrolli kollha fuqhom min lordni tal pajjiz li mandiex fiducja fihom.u irridu  ikunu kollha imlaqmin u bil maskra min jattendi u izommu id distanza.hek biss tista tkun aqli u ihallihom issiru.oppinjoni tiei.jew hek jew xejn.',
#  'Ser ihabbar li jkun hemm bzonn',
#  'Celebrazjonijiet tal festi',
#  'Fuq x iex et nitkelem pls',
#  'Matthew zammit kemm int vojt',
#  'MA Zara exactly,old people from september',
#  'Fuq lis sptar.... Ma smajtx xejn.. Ghadni nistena pls... Ilni sena u fuqhom nistena opp u ohra stand by... Incempel u jaghdulek ghandek.. Ragun ma nafux hu pinoli ta ugieh..',
#  'Many thanks u le',
#  'X qalu pls?..',
#  'Ahjar thabru xi haga fuq lisptar u operations ax Andi tifel ta sebtejn ilu jistena Sena Al operation',
#  'mghandekx ghagla biex tifthu l ground u kollu ifthu, malta biss bil ground maghluq',
#  'Margaret Abela Jackson too soon we just took it and it lost the immunity a lot of rubbish',
#  'MA Zara for nothing I think ,cause theres one in ITU who is vaccinated',
#  'god bless you god be with you',
#  'GOD be with you Gabriel Kurragg Mario',
#  'Hawn sabih.dik it-tbissima sabih avolja tkun miguh.qed nitlob hafna ghalik.gws.xxxxx',
#  'Kurt.Gabriel.nitolbu ghalik',
#  'Proset Gabriel.',
#  'Keep going.',
#  'You can do it bit by bit ',
#  'Il bambin mieghek Gabriel',
#  'Keep on going kid, ',
#  'GOD BLESS YOU',
#  'Il bambin mieghek sabih',
#  'jien nara home alone u nitatta bil quilt ',
#  'Mela issa nissejvja im dreaming of a white christmas bil lest xx',
#  '',
#  'Jien ekk namel u vera tirnexxi',
#  'Diska ma tismahhix...Kanzunetta jew Song nisma jien.',
#  'Business',
#  'GRANDE ERIKSEN ',
#  'Great news',
#  '',
#  'Good news!',
#  '',
#  'Good news',
#  'Take.cary.',
#  'Ukoll xejn ma jonqosna',
#  'Mela li hadna x inhu ??',
#  'Iehor ghal?',
#  '?',
#  'Izommuh jekk hemm vaccin gdid li hadt hadt u daqsek',
#  'Kollox business msieken ahna kulhadd jipprova fuqna',
#  'Fu@@ off',
#  'Mela hasbuna qedin nixorbu il vodka ha noqodu inhaltu',
#  'Se jkun hawn vaccin iehor gdid flimkien ma pfizer u astrazeneca u Moderna u Johnson jismu Novavax.',
#  'Dan aktarz jitqassam f pajjizi li ghadhom lura fi tilqim',
#  'Vax loading....more to come..',
#  'Booster maybe?',
#  'Taqra certu kummenti tahseb li certu nies qatt ma kellhom bzonn medicina jew pirmla, ma jsibuhiex in stock u jixtru ohra bhalha li jkollha l-istess effett.',
#  'Tista zommu li hadd hadd sfortunatament \U0001f972',
#  'La wiehed la tnejn u wisq inqas tlieta',
#  '🤦\u200d🤦\u200d🤦\u200d🤦\u200d',
#  'Li hadt hadt!!!',
#  'Mur ara xi swietilna??',
#  'Biex tmur bicca holiday sa sqallija xeba nejk meraq hara u xorta bl swab u kummidji..   stajna ma hadna xejn!',
#  '!',
#  'Testing fuq l poplu imma!!!!',
#  '!',
#  'Issa li hadt w daqshekk',
#  'It 3 doza It 3 injection ???',
#  'Ghiduli li din cajta u daqsekk qisu qatt ma kien xejn ejja  ma tarax.. mela qed tahsbuna gbajna naraw it tlugh u l inzul tax xemx jew ',
#  'Victor Caruana qabel tghejd ghan nies kun cert li jistaw jiehdu medicini  ghax ezempju jien allergika ghal medicini u ma jtuni xej',
#  'Ramona Briffa u int tahseb li qed nghid ghal nies bhalek?',
#  '?',
#  'Victor Caruana jekk trid tohda int huda  jien mux grudin jespermentaw fuqi issa izejd kollu zejjed -_-',
#  'Enrick Attard hadd ma qallek huda',
#  'Alxejn .',
#  'Bux sifirt u gejt xorta qadt kwarantina ax mir red zone.',
#  'Jin  stajt ma hadt xejn.',
#  'U plus li xorta balla hassle swabs fuq swabs.',
#  'Jin fi frar hadta both doses.',
#  'U qljat qalbi bix nsiefer',
#  'Tiehux hsieb fil vina t onqi ha niehdu!',
#  '!',
#  'fl ahhar.',
#  'wiehed li actually ghamlu studju sura dwaru.',
#  'hopefully jidhol Malta',
#  'Il bambin mieghek sabih',
#  'You are in our prayers',
#  'In my prayers god be with you   keep that happy smile',
#  'GOD BLESS',
#  'Always in my prayers.',
#  'In my prayers',
#  'Fit talb taghna sabih  il bambin mieghek ',
#  'U min jaf kemm xtaqu li ma hadux il vaccine dawk li mietu kawza tal vaccine',
#  'Daqs kemm qeda toqtol nies il midja lanqas il cancer ma qatel nies daqsehekk',
#  'Gwida jaqaw ghandkhom il commission fuq il vaccin kif dardartuna kuljum l istess diska.',
#  'Dak destin hi ma ghandux x jaqsam vaccine u mhux',
#  'U xgaranzija kellu li kien isalva, daw l affarijiet l ebda xjentist ma jafom...',
#  'Buuahahaha ha niehduha drawa din gejja trend nahseb ',
#  'U nies bhal dawn xtaqu li ma haduiex!',
#  'One sided media!',
#  "Either publish all news and facts or don't publish anything!",
#  'https://m.youtube.com/watch?v=zp_zNSEW1wc&feature=youtu.be',
#  'You seriously need some good journalism over here..',
#  'Ledia Bimbli mind games!',
#  "They only mention the people who didn't take the vax.",
#  'They NEVER mention people who the next day after vaccination had serious complications including deaths!',
#  'Ledia Bimbli',
#  'Qazzu l min hallaqhom',
#  'Mel Vella Garko Kuljum l istess',
#  'Leonard Brincat ha jkomplu jgennu lin nies fragli jahasra',
#  'Mel Vella Garko Aktar hawn nies qed ibghatu min depression u anzjeta milli bil covid',
#  'Leonard Brincat ticcajta u tbati l immune system jahasra',
#  'One sided, biased journalism!',
#  'Mara tmut bil (jab) wara jumejn, dawn hadd ma jghidhom',
#  'Gifieri rridu xi certifikat iehor issa?',
#  'Daqt nigu passatur mela ghax wara it tielet tigi raba etc.',
#  'Zewg dozi mhux bizzejjed???',
#  '?',
#  'Mhux ek insa',
#  'Xix mela sa noqodu nitaqbu jewww ',
#  'Tuzzana ohra nihu mux it tielet wahda mela ha noqdu nihdu lingekxins gejjin ijsna passatur biex xorta tista taqbdek din ghax kiku ma taqbdekx paccenjza tejd memx xtamel imma xorta tista taqbdek hafifa u le xorta tkun qabditek🤦\u200d🤦\u200d',
#  'Lisa Bonello dak biex iggibna passatur',
#  'Ritianne Abela mux ac certifikat ghax gejjin ijsna passatur',
#  'Izrael hemm min qed jiehu wahda kull xahar 🤔🧐',
#  'Lisa Bonello tagilx ax ga axaqnija bi tnejn, niehdu iktar jonqosna',
#  'Its only business....',
#  'Il gvern andu jofri tests bxejn biex wiehed jara adux auto immuned.',
#  'Mhux jaqbad u jbelalek l vaccin esperimentali',
#  'Lisa Bonello ajmaaaaa heyyyyy',
#  'Noooo way 2 bizejjed  u izejjed',
#  'Shea Abela Vera dwejjaq  li noqodu  nihdu  izjed  .',
#  'Imma  taqbdek  hafif  mod u tibghatek  ghand alla  mod iehor  tikonfondi  xtaqbad  tghamel  ma kienx  virus',
#  'jigifiri isa kollha kemm ahna inriedu nergaw niehdu 3rd dose?',
#  'umbad 4th u 5th u 6th',
#  "Barra min Malta bhal Israel ga bdew johduha ima dawk l'iktar vulnerabli min 60 yrs il fuq biss !",
#  '!',
#  'Anke ir 4 filkas 🤣🤣',
#  "As long as it's the same dose.",
#  'Some countries do not accept mixed vaccines',
#  'Omg ghadni laqas irkuprajt min l-ewwel doza ghadew 5 months ahseb u ara',
#  'Shea Abela ghandek ragun izda jien naf kaz ta xi hadd vaccinat li qabdu l virus, u xi hadd li mhux vaccinat.',
#  'Id differenzi li kellhom kienet kbira.',
#  'Persuna on the verge ta sptar u persuna ohra bla sintomi.',
#  'Li ha nihdu 3 wahda hadd ma qalilna u ghal darba ohra tnejku binha f wiccna 🤣🤣',
#  "Il boosters dahlu f'sormkom ja imbecili",
#  'Irene Irene l ajja li tqabdek... tahwid ta hormones....',
#  'Kien hemm ghalfejn iggibu ritratt tal prominad u l knisja ta Bormla biex tiktbu dan lartiklu billi min ghamel ir reat hu minn Bormla kif qed tghidu ma jfissirx li l poplu Bormliz kollu listess  Biddlu dan ir ritratt min  hemm ir razzizmu mhux fil kulur biss jibrilla mill Maltin imma ghanka bil lokalita Nehhu dan ir ritratt',
#  'Naqbel.',
#  'Proset.',
#  'Basta jisemu lisem bormla hi',
#  'Kellkom ghalfejn igibu bormla ;',
#  'Davinia Busuttil Ghax sfortunatament Dav, jekk tajd li int minn bormla hawn malta daqshekk hi hadt fama hazina .',
#  'Laqwa li ngibu artiklu hu daqshekk  .',
#  'Veronica Maria  hekk hu njoranza bazwija',
#  'Davinia Busuttil Ghalhekk hawn malta qatt ma nimxu l’quddiem ',
#  "Għax f'dak pajjiż għax tkun minn Bormla tkun ħażin, aħjar jaraw fejn iriduha tal-qaddisin u jaħraw ix-xjaten.",
#  'Ċertu nies ommi ma.',
#  "Taf xiex li biex jiktbu artiklu naħseb anke l'ommhom ibiegħu ċerti nies għax ma jkunx hawn bassa li ma jidħlux fiha",
#  'Li tafda tajjeb li ma tafdax AĦJAR',
#  'Rest in peace MY CONDOLENCES',
#  'RÌP',
#  'Mhux jaraw min kien ix xuffier u jkelmuh mela qisu xejn mu xejn',
#  'Ix xufira tal linja bicca minhom qisom xi allat ma tistax tkelimom',
#  'Aw hafna xufira baranin u et iqazu lalla  kem kona  ahjar meta Kona  Blantiki xufier malti mawx phalu Xi hadd qall soica zmien il buzulitti Flok rit jajt se jibda zmien il buzuloti Sur  Aston  gatt  u dal purcinell m delia   hxew transport  publiku',
#  'Jin meta nitla bil puschair lanqas biss inzel ftit biex nitla bih dawn il filipini fil veru sens tal kelma demel toqodilhom',
#  'Bla qalb in nies ufffff Lanqas li kienet wahida ma nizila timxi fdin il qilla ta xemx ahseb u ara b tarbija maghha Maltija kienet??',
#  '?',
#  'Di ta cents iridu jaqtawa ax xorta flus huma.inkella meta jatuk il pqijja bijom .waddabomlu al wiccu .jazlu nies nahseb .ma nkunx jin tejd .ehh',
#  'Kont nirrapurtah',
#  'Kemm nejr ghal nies li exu 30sena ijlu kinu inizlu il kapell xhijn tadi issa hlif jistmawk fil 🥔 majamlux🥺',
#  'Jien nara hafna mjn dawn lesperjenzi illi anke ma tatijomx ezatt hawn minnhom jaqbdu jajruwom biex jjnzlu .',
#  'Darba jien kien em student sejjer l iskola  minhdejn il junior college u ma kellix biz zejjed ghax qomt biex natih il kumplament ix xuffier tghidtx kemm ghajjarni sa hansitra ried inizilni miju .',
#  'U qabzu xeba nies alek  saq',
#  'Dan ix xufier haqqu jigi suspendut  ma kellu ebda dritt ikun arroganti lanqas gietu hniena ghal dik it tarbija , Ftit huma dawk li jhennu ghal proxxmu.',
#  'Lily Grech kienet xkienet kellu jgib rispett lejn dik it tarbija  hi kienet edukata biżżejjed',
#  'Allura hadd ma ghina.jhallsilha.',
#  'Verita ghax meta kont nuza tal linja kont niltaqa ma hafna sewwieqa arroganti.',
#  'jew ohrs skuza tsl virus jek ittihom aktar minn Sippost ma jtukx bqija mux kolla jamlu hekk',
#  "madoff x'faqar gejna fih 2021",
#  'Uhud jahsbu li huma xi Alla .. a tista tkellem lil hadd!',
#  '!',
#  'Joseph JoJo Azzopardi   insejtu kemm kienu jajruwhom li xufira     ghax ma ftitt jehel kulhadd issa qieghed tajd ahjar  ix xufira maltin   ghax il qawl malti taf xinu   mal hazin jehel it tajjeb f kollox',
#  'Antoinette Farrugia Ezatt proxxmu kienet kemm hi u kemm it tarbija irid ikollok stonku biex tnizila min fuq mater dei bus b tarbija f idejha',
#  'Miriam Lazoumi ehe ahna konna tajnih 5euro u qalilna ma natux bqija habba il covid ndunajt li mux vra ax mbad haddiehor bdew ituna il bqija .. ja bicca ta zibel li.uma ...',
#  "Joseph JoJo Azzopardi ma tantx għax jien niftakarhom ineżżawk b'għajnejhom u jekk titla' xi mara anzjana ma jtuwiex ċans tpoġġi.",
#  'Jekk ittijhom flus ħażin iwadbuhom barra mit-tieqa.',
#  'Lily Grech setet kienet gejja mill ghadira ahseb wara minn mater dei  nies bla qalb',
#  'Kieku kont hemm jien u ikoli is zghar zgur kont inhalsila ghax Gili gratli u issa iktar u iktar ghax saru iridu blezatt.',
#  'Gili inkun jien u tifla u ikoli 5 euros.',
#  'Ta tnejn 4 euros jekk ma ikolikx flus fil card, izda jekk itih 5 ma itikx bqija ta 1euro.',
#  'Hawn hafna xufira Barranin u arroganti.',
#  'Nies bla qalb',
#  'So sad, if you lose humanity there is nothing left, solidarity with this lady, these drivers should be grateful that they are working here and show respect ',
#  'Blessed little boy ',
#  'Xi hlew god bless',
#  'Hanini god bless ga jaf jghazel e🤣🤣',
#  'How sweet',
#  'Xhlew',
#  'How cute!',
#  'Super cute harry :)',
#  'Stick to music Harry :)',
#  'Hanini god bless',
#  'Xi ħlew 🥰',
#  'How cute',
#  'How cute',
#  'Xi hlewwww.',
#  'Jaf jaghzel midhera  Ghax moira ghalija wahda mil lisbah mara maltija',
#  'Hanini xi hleww allajbierek ',
#  'Min ckunijtu mux cuc it tifel hi jaf jazzel hi rajtu god bless',
#  'Jag jaghzel hux?',
#  'Hannini xihu helu.',
#  'Hannini xi hlew 🥰🥰',
#  'Wisq xi hlew harry',
#  'Kont xi darba fan tieghak ghax kien minghalija li thobb lanimali u li tamel kollox ghalihom bhal ma tajd imma parolli si fatti no int',
#  'hehe xi hlew.',
#  'Sooo cute ',
#  'May he rest in peace.',
#  'Id destin hawn minn ħada u miet u hawn minn għadu għaddej bil konsegwenzi tagħha.',
#  'Ħafna huma dawn so duk il ħajja jew vi jew va kif tiġik',
#  'Mela mhux bil covid miet bil mard Tal qalb so ghala tallamaw in nies',
#  'Ir Ragel minn Sydney (mhux malta) u Jeżistu wkoll xi kundizzjonijiet tal-qalb fil-familja Al-Askar, u l-kuġin tiegħu, Khalid Thijeel, qal lil Daily Mail Australia li jemmen li kien dan li temm ħajjet ir-raġel, mhux il-virus.',
#  'Romina Micallef U jekk mhux b hekk tmut b haga ohra,ghax ghall aw m ahniex.',
#  'Dorianne Agius veru he ',
#  'Tafu kemm aw nies li MIETU bil vaccin u l daw qatt ma ssemmuwomx ????',
#  "Kollox pro vax biss aw Malta , I'm sorry , imma it's not about health jekk ha toqodu 24/7 xxandruwa minn naha wahda biss , isu guilt shaming il min ma hadiex !",
#  '.',
#  'Hallu l kulhadd liberu u ma noholqux firdiet fil poplu',
#  'Abigyayle Griffin',
#  'Adrian Galea imbasta jaqbdu u jpecilqu.',
#  'Ara vera dejjem tbezzaw in nies ...brainwash bil pulit !',
#  '!',
#  'Romina Micallef totally agree',
#  'Taghmel ghal ahjar dejjem tiehu vaccine imma ma jfissirx li tkun infallibli.....Jien tlift nies qrib tieghi bil covid u anke ohrajn li kienu hadu lewwel tilqima ....oqodu attenti u zommu mal protokoli',
#  'Silvana Borg biex min ma hadix imur johodha nahseb ghalekk.',
#  'Gurnalizmu tal Bigilla!',
#  'm humiex certi, imma jekk ikun hemm problemi ta sahha, il covid ghandu mnejn ittemlek hajtek',
#  'Jekk taqrae sewwa l artilu mod u l istorja mof iehor.',
#  'Kuginuh qal li hemm xi mard filfamilja li seta miet bih igifieri ghadhom ma jafux ezatt biex',
#  'Headline qarrieqi ghall-ahhar !!!!!',
#  'Pffff.',
#  'Xkumbinazzjoni ux',
#  'Li tbezzgha huwa kontroll!',
#  'Mhux ahjar jintqal kollox!',
#  'Mela dejjem jintqal li dak li gara ghax ma hadux il-vaccin?!',
#  'Tafu kemm hawn nies li hallilhom konsegwenzi koroh hafna bil-vaccin u anke hemm min miet ukoll!',
#  'Imma le!',
#  'Bizgha biss ghax ma haduhx!',
#  'Jew inkella li mietu ghax kellhom kundizzjonijiet ta sahha ohrajn, bgal dan il-kaz?!',
#  'Ieqfu bezzghu u tghawwgu l-fatti!',
#  'Auguri Claudia.',
#  '🥂',
#  'Happy birthday',
#  'Awguri',
#  'Awguri ',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri 🥂',
#  'Awguri',
#  'Awguri',
#  'Awguri ',
#  'Awguri',
#  'Happy Birthday!🥂',
#  'Happy Birthday ',
#  'Awguri',
#  'Awguri',
#  'Auguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri ',
#  'Happy birthday 🥳',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Happy Birthday',
#  'Awguri',
#  'AWGURI',
#  '',
#  'JINQA Kinet Talimni il Florjana At Makelqi PROBLEMQA Maha ANZQI Kinet Tara kijf Tejnqi   u Vera Ticer Bravqa HAFNQA U Tkoplqi ma kul Hat',
#  'Such a sincere comment builds the self esteem he maybe unkowingly lowered.',
#  'Awguri.',
#  'Awguri',
#  'Awguri kugin tikber qiegheda',
#  'Awguri',
#  'Awguri',
#  'Proset kemm huma kliem sbieh.',
#  'Awguri',
#  'Awguri',
#  'Awguri ',
#  'Awguri',
#  'Awguri',
#  'Awguri cousin',
#  'Awguri',
#  'Awguri god bless.',
#  'Awguri',
#  'AWGURI',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Kemm ikollna dinja ahjar kieku tfal kulhadd jaghlimhom dawk il kliem kemm ikun hawn paci fi dinja',
#  'Kuragg',
#  'Kuragg',
#  'Kuragg',
#  'R I P',
#  'May he Rest in peace ',
#  'May he rest in peace',
#  'Rest in peace ',
#  'Ukoll.',
#  '',
#  'Ukollll',
#  'Hazin hafna🤣',
#  'Ahjar forsi ma tigix ix-xitwa.',
#  'Naqa min kollox biex naqtaw zgur ha nibdew',
#  'Ara shun niexef u maltempati qawwija …… mur ifhem ijsek hadt kebabb mixed ha tkun doqt mit tnejn ',
#  'tixtrux hwejjeg tax xitwa mela kulhadt ifaddal',
#  'nixfa u maltempati hmm lol',
#  'Ma nistax nifhem, b maltempati, jew shuna, u niexfa?',
#  'Isa hej x gost ',
#  'Ajma hej...mela l istaguni ha jigu sajf BISS ',
#  'Tal biza',
#  'They must come and clean the Culvers',
#  'Xem u  xita Alla jaf meta, jekk qed ninqlew, f zejtna stess qed nigu grilljati.',
#  'Ejja nibzghu ghal ambjent ghax dardarnieh...',
#  'haluh ha jamel alla qas bis nafu ux ha nibqaw hajjin sa lejla kollu tbassir u paroli vojt li andu jigri jigri u daqshekk',
#  'Ha nibdew nivvintaw .. artiklu Tal futur ..bla sens',
#  'Ahna ahbarjiet phall kesha maltemp silg hekk irridu',
#  'Desertification ma tridtx tkun xi gharef biex tinduna li Dak huwa l futur taghna.',
#  'Qas nghati 10 snin ohra cans li jkollna dit tip ta Shana s Sena kollha.',
#  'Ghad irridu inpattu ghal hsara li ghamilna l ambjent ta madwarna.',
#  'Anita Mizzi mhux li kien dejjem sajf!',
#  'U aqtawha dejjaqqtuna jaghmel li jrid qabel l ahjar rapport tat temp wiehed u daqshekk.',
#  'Jennifer Pace maaaaaa bla sahha jhallik',
#  'Enjoy your building now .',
#  'Changing the surface of the planet is what is creating climate change .',
#  'Louise Portelli our kids are f big time.',
#  'Green leaves Swatar dejjem lesti biex jaqduk u dejjem bit tbissima .',
#  'Sandra Borg , Susanne Schembri , Jean Paul Parnis , Darren',
#  'Xi pakistan mil pavi ',
#  'Dan xkien mhux kollox sponsor is soltu',
#  'Marlon Destiny Gafà tghidx kemm jitbismulek dawk!',
#  'Kont ta 5minuti taghmel kwarta..',
#  'Patrick Mugliett  ta grazzja store fgura mil koxxa jaqdik',
#  'Bidell naqra  id  diska',
#  'St martin confectionery zurrieq',
#  "Għalfejn irid idaħħak b'dak in-nuccali?",
#  'Ħa nibqgħu irridu ndaħħku bid-difetti.',
#  'Angelo Verde Hal ghaxaq ',
#  'U zgur li tbellah.....ghax is soltu kollox bxejn jiehu !!!!',
#  'U fil fatt dan riklam ukollllll',
#  'Vojtagni ta jaq',
#  'Miskin qas kien jaf....gurnalizmu jaq',
#  'Green leaves  Swatar, Sandra Borg, m hawnx bhala dejjem bit tbissima u lesta biex taqdik',
#  'Mhux bic cajt iltaqt mghhom kolla .',
#  'Prosit  billi tidhak mafija xejn hazin sa khemm jkollok is snin',
#  'Skunju Market Zurrieq  the best',
#  "Meta mmur nixtri bil-flus immur fuqi, biex ma nippretendi xejn, b'xejn.",
#  "U m'inhiex tallab lanqas.",
#  'Camilla Dei Medici',
#  'INHOBBU JIENA',
#  'R.I.P',
#  'May he rest in peace ',
#  'May he rest in peace',
#  'Proset.ill.puluzzijA',
#  'Solidarjeta',
#  'Soludarjeta ma dawn il puluzija',
#  'U km ghat ikun aw ghar kollu bidejkom qedin igibuh dan',
#  'Ibatuh lura.',
#  'cucata ax wegga lil pulizija hazin ax familji andom',
#  'Pulizija ghandhom ikollhom section apposta li tkun stand by ghal kasi ta vjolenza.',
#  'Jigu bil van u jkaxkru lil.dak li jkun, mhux tara erbgha zghar ma gladjatur.',
#  'habta rashom tajjba mal hajt sa ma tinffaqa l iskuttella ta rashom halli ikunu jafu x garbu il kuntistabli waqt il qadi ta dmirijithom',
#  "Rajtna x'niehdu talli nilqawhom hawn hi!",
#  '!',
#  'mhux bilfors jigri hekk.jekk qorti korrotta u nofs il-parlamentari avukati mhux ligijiet favur il-kriminali jfhaddu mhux maghhom jieklu,c-cittadin onest biex ihallas t-taxxi biss',
#  'He should sent home.',
#  'As soon as POSSIBLE.',
#  "Solidarjeta mal-pulizija li jkollhom ihabbtu wicchom ma dawn it-tip ta' nies wara li Malta tkun laqathom.",
#  'Jahsbu li Malta gungla wkoll.',
#  "Back to Nigeria that's all.Dak l alarm phone!",
#  'Issa nispera jhallas ad danni u jintbat lura pajjizu',
#  'Dak kin ilu jamel hekk fuq karozzi.',
#  'U saru rapporti.',
#  'Fl ahhar qabduh.',
#  'Solidarjeta mal-pulizija',
#  'Intlejna bl-imbarazz kollu li pajjiżi oħra ma jridux.',
#  '',
#  'Barra',
#  "Hekk sew ma jobdux or regoli ta Malta u sawtu puluzija taghna I'ma tahom ma jsatuwhom ax Mal lewwel jinzlu ma lart mejta awn jaghmlu larja",
#  'Imbad ax il Malti jgerger, jigi majjar razzist!!',
#  '!',
#  'Kif issoffri griehi?',
#  'Ghadhom bla tazer?',
#  '.... ta lanqas lembumba extendable ..?.!',
#  'U 2 fuq wiehed...!',
#  'Ghqndhom bzonn Tazer halli jevitaw kemm jista jkun physical contact.',
#  'Niehdu l grazzi talli salvawhom mhux hekk!!!',
#  'Ibghatuh minn fejn gie!',
#  '!',
#  'ibatuwom luwra fpajizom',
#  'Ukoll ejja inkomplu inhennu',
#  'Hemm ahna same old story,sa jigri issa?jigri ma toroq mal kumplament li haw ,ma nahsibx al barra ,din haga serja hux.',
#  'Jaff jisthi il gvern wara diek il korozjoni tal electro gas',
#  'Tal biki',
#  'Dan mu xejn qabel konna kull tlet ejiem konna inkunu bla dawl .kullhadd jinsa jahasra',
#  'U l aqwa fl ewropa jghidulna',
#  'Min jaf kemm aw faqar li mandomx Ac dar kemm ibatu iktar minna imsiken ',
#  "Joseph Vella  jisthi minn x' hiex!!",
#  'Jisthi min qal ha joghlew il- kontijiet.',
#  'Jisthi dak linhalla power station tahdem bil- heavy fuel oil.',
#  'Jisthibdak li halla l power station tal - Marsa.',
#  "Jisthi dak li halla t- tankijiet ta' B' bugia.",
#  'Nkompli!',
#  '!',
#  'Alistair Scicluna hekk hu',
#  'Heq mela Ek namel kieku',
#  'U zgur li tal misthija.',
#  'Mla sew ragel jahdimlek Gurnata shiha fi xemx umbghad jigi biex jorqod u ma jkunx hemm dawl.',
#  'Lejl bla rqad u l"ghada trid tmur terga xoghol barra.',
#  'Mhux easy lejl bla rqad u tqum ghax xoghol fil ghodu.',
#  'Joseph Baldacchino Ghax Kulhadd Derha Fil Kumdita Hux Qabel Xkienu Jghamlu?',
#  'Joseph Baldacchino L-ixkubetta fiha grillu........u kulħadd jagħmel li jaqbillu!!',
#  'Naħseb fhimtni Joe!!',
#  '!',
#  '2021 🧐',
#  'Joseph Baldacchino tkunx kif qalek ezl 🤣🤣🤣 qabel dejjem semghu qabel .Mela ghalfejn dak tanker ??',
#  '?Ok ghal korruzzjoni electrogas .',
#  'MELA VERA KULLHADD JINSA KEMM INQATA ID DAWL QABEL .AX MA TIGHDUX .LI HAWN HAFNA FAMILJI LI JUZAW A C IL HIN KOLLU HU QEDIN OVERLOAD',
#  'Sewwa ghamlet, l istess kont naghmel kieku',
#  'Uffa xi shana \U0001f972',
#  'Anna Cachia temperatura ta zmienek differenti mil illum ta',
#  "x'differenza s-shana li qeghda taghmel issa min dik ta' meta kont tfal inti, anki min sajf ghal iehor naraha li s shana zdiedet ahseb u ara!",
#  'Anna Cachia  Dak zmien u Issa iehor move on',
#  'Kim Berly le ta 🤨 jiena fit tieġ kien 40•C.',
#  'Heat wave 1978.',
#  '1988 Konna se nmutu meta telgha 41•c.',
#  'Kont qeda nistudja l italia.',
#  'Ir- rails tat trains kienu nħallew!',
#  '',
#  'Kienet taqbez il 100 Fahrenheit fis-sajf meta konna tfal!',
#  'Gieli rqaddna fit-terrazin ahna.',
#  'Is shana ma zdiditx ... li gara drajna nghixu fil kumdita...inkluza jien.',
#  'Anna Cachia jien ukoll ax meta kelli 8 snin gie dawl fid dar li konna nighxu fija batejt vera ax listudju bil.lampa tal pitrolju kont namlu',
#  'Anke ahna ma kellniex ac.',
#  'Imma kelna fan idawar naqa l"arja mhux xejn ghax ma jkunx hawn dawl',
#  "Mela sewwa ghamilt mela toqghod fis shana Xi rimedju trid isib Jien naf min li biex jorqdulu tfal imur dawra ma Malta f'xi satejn ta bil lejl",
#  'Ma hemmx l power Station l gdida ',
#  'La hemm Power Station gdida nghid jien kif dal qtuh kollu.',
#  "Il pajjiz zdied fil popolazzjoni u domanda ghad dawl kibret ukoll b'hekk, allura suppost kienet mahsuba li domanda se tizdied.",
#  'Marica Farrugia biex tiktbu addocc facli imma biex taqraw stqarrija ssibuwa difficli',
#  'Mhux ovja li kienet ha tizdied id domanda',
#  'Ghabel dar kull 100 kella A.C u illum kull bloka ta 80 flet go fija kollha ghandom A.C xmajmurx id dawl din il problema kull sajf u listes fixitwa meta tkun il kesha .',
#  'Speechless',
#  "Il prezz li qed inhallsu  bl-eluf ta barranin li qed jghixu f'dawn il gzejjer, minbarra, sptarijiet, dhahen tal Karozzi, u zvilupp sfrenat specjalment bi tqaccit ta  sigar.",
#  "Mn' Alla bhalissa  neqsin sew mit turisti gol lukandi,  ghax kieku ma nafx kien jigri.",
#  'Yes and the more you build apartments the more energy you need to provide.',
#  'Anybody discuss this before you start digging, destroying the environment all for profit.',
#  'Hemm bzonn li l-popolazzjoni fuq dan il-kontinent li jissejjah Malta tkompli tikber u l-problema tigi solvuta!',
#  '!',
#  'John Zahra hekk hsibt jien ukoll',
#  'Jc Sel dik il verita habib .',
#  'Marica Farrugia il power station ghanda hafna aktar mid domanda dik mhux problema imma is sistema tat tqassim bhal substations ma jifilhux ghad domanda meta fi triq ikollok 10 djar jitwaqqaw u issiru mitt appartament b mitt meter u tlett mitt air condition.',
#  'Il gvern, ma missekx mort titbassas biex il vapuri tal passigieri jiehdu id dawl mil lunika power station li ghandna, inti kont taf ser jigri u xorta ta rasek ghamilt.',
#  'It seems that the problem is not the power station itself but the Sub-stations .',
#  'Supost laqwa fid dinja Malta u power station ma tiflahx ghal cert domanda ta electric ..dawn laffarijiet jigru f postijiet fqar mux fpostijiet top of the world ... Imma xtamel pacenzja tamel iljieli bla ac..',
#  'Basta kollna pipelines u gassijiet u dik li qedin niehdu',
#  'Izjed mhu ha ikun hawn bini u flats izjed ha jinqatta id dawl imma la jafu bil Problema misshom jaraw xha jamlu ax il quddiem mhux il bod il problema ha tkun ikbar …u jekk din il problema qed tigri spiss issa Nisperaw li il kontijiet mhux jintbatu bl-addocc…copy & paste 🤬',
#  'Id dawl li tkun overload nifimha imma it tbazwir fil kontijiet huwa kbir al minn ma jifhimx',
#  'Basta ftahharna bil tanker tal gass.',
#  'Hela ta flus .',
#  'm hemmx skuza ghal dawn l affarijiet, kull ma trid ftit hsib qabel.....ma tohorgux permessu ghal aktar bini sakem issolvu l problema ....as simple as that!',
#  'Mhux bilfors trid tkun aref🤔jekk kul sena jinbina il bini u kulhadd bl AC ilum mhux kapric ima necesita sar',
#  'Lawrence Spiteri',
#  'Mhux apologija imma jinaghtaw kumpens',
#  'Sfs',
#  'R.i.p',
#  'Sfs',
#  'Salvagizmu u njoranza grassa ghandu da l-kaptan...ta min johodlu l-licenzja!',
#  'LI kieku ma kienux jafu jghumu setghaw gherqu la IL kaptan gie ghala biebu',
#  'Tiziana Casha u jitfawh il habs ghax seta qatilhom',
#  "X'arukaza.",
#  "Dan x'kaptan hu.",
#  'Kellu bzonn jeqlibhom!!!!',
#  'Nispera li jittiehdu passi kontra dan il kaptan.',
#  'Dan il kaptan ta min jehodlu il warrant  ax dan jigi attentat ta qtil volontarju',
#  'Xpastazata kulhad jamel li rid ma setax qalilom',
#  'Tal kaptan ghandu jitalla il qorti u jehel multa tajba inkellha ha jibqa jghamel kulhadd li iried ma nahsibtx li kienu jafu li ma jistawtx joqghodu hemm kiku ma kienutx imorru hemm zgur.',
#  'La kien wiqaf il kaptan responsabli',
#  'ISSA naraw tinqatax malajr bhal ta dawk iz zewg ommijiet u povri toddlers',
#  'Dan-il kaptan ta  min johodlu l-licenzja?',
#  'Attempted murder!',
#  'Nispera li dan iz zibel li ghamel ma jibqax is suq id dajjes ax jehel dak li haqqu',
#  'Nisperaw li din id darba il qorti taghmel xoghola sew ghax ha nigu f sitwazjoni li trid tiehu il ligl b idejk',
#  'Imisshom irrapurtaw lil tm.',
#  'Il flus triq fil bahar jghamlu.',
#  'Mux xi 50 euro multa u ijsu xej mu xej la dawk tal fishfarms jamlu li jridu',
#  'Jin qem inkun ukol imma fil verita manistax imoru nistadu qem matistax tithol il gewa mil zibruni hibb',
#  '',
#  'Pajjis tal gungla',
#  'Malta tan nejk kullhadd jghamel il ligijiet kif jaqbel lilu  anke fuq il bahar issa mbilli kienu qed jiehdu ftit gost jistadu kellu ghalfejn jsuq ghal fuqom',
#  'Ipqaw parlaw fil vojt fuq din stenew li jibdew ikeccu lil kulhadt',
#  'Well fish pans are in our sea and they make it theirs with such aggression.',
#  'What difference does it make if they managed to fish for a couple .',
#  'I m sure they are not going to be bankrupt.',
#  'Qed naqra, u jiddispjacini hafna ghalihom.',
#  'Nista nobsor kif tinhasad.',
#  'Ahna gralna hekk dahal fina valur Malti  lejn tas-Sliema Malta daqs 36 sena ilu.',
#  'Farrakna, waqajna l-bahar, tlifna kollox u biex taxxaqa jiena kont tqila kelli xi 3 xhur tqala.',
#  'Nirringrazja lil Alla li ma gralna xejn gravi.',
#  'Storja tal-biza.',
#  'QATT ma ninsa.',
#  'Madx fadal rispett ta xejn.',
#  'Jien milux cempili wiehed fit tard bejn id 9.',
#  'U l. 10 ta bil lejl, jipretendu lk tkelimom fuq xi xogholijiet.. Jew icemplulek il hadd, jekk ma taqbadomx jifqawlek mobile icemplu',
#  'Rispett fid 9.26 pm u taqtala terga icempel u tejdlek ghax inti qtajtli u trijd taha minfuq fuq laundry mhux fuq medicina jew ikel',
#  'Anzi ma jibatulekx ?....??....???',
#  'Messagg  wara iehor biex twegibhom!...',
#  'nkella icemplulek 4am  u tkun rieqda u jghidulek ghax qbadt il van ghax xoghol u nsejt li ghadu l hin!',
#  '!',
#  'Joanne Micallef Garrett jew xi  ???',
#  '?',
#  'Alison Agius ekk hi wara xulxin!',
#  '!',
#  'Joanne Micallef Garrett naf X jigifiri tibzax',
#  'Sibt, Hadd... il hdax, nofs il lejl....',
#  'bl-istess ragunament, ghalfejn ghandhom jifthu i-hwienet tal-hwejjeg, supermarkets etc nhar ta Hadd?',
#  'Sa ftit ilu kulkadd kien isib hin imur jixtri bzonnijiet ta kuljum, hafna mill-hwienet jifthu tard matul il gimgha ukoll biex kulhadd ikun moqdi.',
#  'Ghandna ghalfejn immorru is-supermarket il-hadd ukoll?',
#  'Patrick Tat-towing L-Ginger......ghidilhom naqra!!!',
#  '!',
#  'Jien jekk nibat xi mistoqsija fil weekend ma nipretendiex li jirrisponduni, jirrispondu xhin ikunu komdi',
#  'Ma fadalx sibt u hadd.',
#  'Iz zmien li min ma jaqbdekx id dar jiprova aktar tard ilu li spicca!',
#  'Ir ragel self employed .',
#  'Anke fil Milied cemplu .',
#  'u messages .',
#  'Minoranza ta ghax ghandna hafna klijenti ta rispett u japprezzaw ..',
#  'skond fuq xiex ax jek xtrjat xi haga min ghandom ilhaqt u inkirt tkun ila laqqas gimgha ila ghandek rejdilom trid ax gili jghidulek issa et tggidilna jew laktar jek tamel xi  gimgha iccampilom bix taqbadon',
#  'Ghax il prudenza u ledukkazzjoni spiccat ara lilna dari kienu jghalmuna ..u dan mil genituri gej',
#  'Injoranza grassa kulhadd irid kollox ma s**** lol u addiu edukazzjoni u prudenza',
#  'No regard for others.',
#  'Prudenza le.',
#  "It's all about me, me me.",
#  'Jien niftakar meta kont zghira ommi kienet tghid, ezempju filghodu kmieni ma ccempilx u lanqas wara 8pm, u bejn 12pm u 3pm ma ccempilx lanqas.',
#  'Il-problema hi li l-maggor parti tan-nies saru jahdmu, u hin biex jibghatu dawn il-messaggi jkollom kif jaslu mix-xoghol, sakem ukol x’hin jaslu d-dar iridu jihdu hsieb ix-xoghol tad-dar lit-tfal etc .. u mbaghad wara forsi jkollom cans … Il-hin liberu sar limitat hafna .. nahseb li dik hija l-problema .. Jien immexxi facebook page tal-business tal-familja taghna, naf ukoll x’jigifieri mobile ma jiqafx minn x’hin jisbah sa x’hin jidlam ..',
#  'Emm bzonn ig gib fb mux tghidilom le u dejjaqlix ghajni punto basta',
#  'Mela mhux bhal dipartimenti tal gvern ta , ghax la jekk icempel la ghax tibat la imejl  xejn ma jwigbuk qatt .',
#  'Joseph Azzopardi kretini l full',
#  'Know the feeling hi 🧐🧐tkun hoilday insiefer lol Ic cemplu ghal xi Haga min jaf kemm iggieldna fuq hekk kont nejdlu armi mobile itfi kien jiejdli ma tistax dor ...ghax xoghol l ohrajn qedin  veru gejjna bhal respect 🤔konna nejdu ghat tobba lol qabel imsiekken....illum kulhadd gie miskien vittimi Tal mobile....ghax ikollok mobile Mela service 24 hrs..',
#  'Patrick Tat-towing L-Ginger bil pedigree',
#  'Veru !!!!',
#  'normalment qabel 8 wara 5 u fil weekend.',
#  'Raguni wahda dik, ghax waqt li inti tkun qed tahdem haddiehor mohhu fl interessi tieghu, kif ikun lest komdu u paxxut sms telefonati u jhekk jista jkun tmur wara il hin ta xoghol tieghek biex hu ma jiehux leave.',
#  'Pastazata kbira dik !!!!!!',
#  '!',
#  'Ikkonsla ghax Id dipartimenti tal gvern qas fost il.gima ma jwegbuk ahseb u ara fil weekend',
#  'James Grixti ghalik din !',
#  'JIENA L- AKTAR LI TOGOBNI  GHADA JISBAH UKOLL DISKA  IMMA LANQAS SMAJT ID- DISKI KOLLLHA',
#  'Lili ghogbitni... Il-Bajtar Sar.',
#  'Song vera helwa .Awguri Dario u Grecia.',
#  'Il manutenzjoni ghandha ssir fl izjed granet tas shana allura nghid jien ?',
#  'U filghodu tghaddija min hemm u min hawn.imma bil lejl veru ikrah .ma tkunx tista torqod u mbad l ghada trid tour ix xoghol',
#  'Jien blajta da lejl hbieb 9   u gi 4  ta fil ghodu wara 12 sija xol qas torqod',
#  'NISPERAW LI Z ZEJTUN JIRRANGAW.IL BICCA FEJN JINQATA KULJUM PLS U FEJN IL HIN KOLLU BID DAWL BAXX!!!!!',
#  '!',
#  'Tafu li hawn nies qedin ġo sodda morda u b shana aktar jigravalom ugieh .',
#  'Ahna wkoll blajnieh ax gratilna hsara kbira fil lift !!',
#  '',
#  'Ahna ma konniex avzati la dal lejl u lanqas issa Zejtun ghax rega’ telaq!',
#  'Dawl qisu Christmas tree!',
#  'Rega mar phase qaluli',
#  'Ma nafx ala bil lejl eee',
#  'Martina  Zammit zabbar!',
#  'Qazew lalla zgur sena wara sena dejjem listes problema 🥵🥵🥵',
#  'Kemm inthom bhahan u tibilaw kollox jahasra.',
#  'Xtipretendu li jghidu li hallasna ghal sippost power station gdida ghaz-z###.',
#  'Ghax ma hemm xejn.',
#  'Hekk jonqos f heatwave bhal din tridu toqtlun nies',
#  'U jk tkun avzata x tista taghmel madonna go din is shana.. ha joqtolna dan is sajf',
#  'Il fridges l aghar',
#  'Povri nies morda fi sodod jahasra.',
#  'Ifrah',
#  "Dawn bis serjeta mela issa jaqqttu I'd Dawl f din is Shana.",
#  'Veru pajjiz ta dahk.',
#  'Arukaza kbira toqtluna tirdu',
#  'Zurrieq 7:00 - 13:00 u haluna minkom !!',
#  'Ilna kwazi 24 hrs jilghab id dawl !!!',
#  'Jitlaq jghamel satejn u jerga jigi.. ga ghamila xi 5 darbiet.',
#  'Harbatnih lejl !!',
#  '!',
#  'MA Zara It’s not ridiculous it’s just an excuse for the gahans around, you know',
#  'Imma qabel Mhux hekk kien jigri wkoll?',
#  'Hekk jirraguna gahan',
#  'jahasra ghandi genituri anzjani bellahtuwhom 5 sighjat  il bierah u erba sieghjat illum  bla dawl eta 75 plus//////tal blieh eh ......ghax ahna ingergru imma nistaportu imma anzjani iebsa ta...........fuq haz zabbar qed nejd biex pls hudu hsieb ......ghax dalwaqt rega diehel il lejl.......',
#  'Kem qedin sew tafu li qawn nies ghanzjani fi sodda u nies morda f heatwave phal din pajjies ta nejk',
#  'R.i.p',
#  'Condolences..may he R.l.P.',
#  'Kyle Cutajar',
#  'Tristan Micallef',
#  'Iva jista ikun trid thafer it triq biex issib il high tention u taqta il hazin fejn jinharaq u tamel gonta li fija xogh u tati il konkos fuqa u tija lasfat bit tarmak !',
#  'Ma qalu xejn hazin imma trid titranga u tihu hafna hin .',
#  'Suppost ha jirrangaw post.post ghax ahna izZejtun tal biza!!!',
#  'U mhu  kollha Zejtun eh!!!',
#  'U very very.low voltage bilkemm nara fil kcina jien filaxija',
#  'Basta Zowzef Muscat kien wieghed li qatt mhu ha jerga jinqata d dawl u gab dak il monstru ta tanker ivota Gahan!!!!!!!',
#  'u emmen mazzun umbad kienu jghidu ghal oposizjoni morru hudu kafe kollha kemm intkom',
#  'Wara 20 hrs il birah fill 5pm gie id dawl',
#  'Isa  jigu ghal-vot brother.',
#  'Jew ha jghatuna discount.',
#  'Ministru  ghara  l-problema.',
#  "Dawn kemm ha jaghmlu ghageb ghax inqata darba I'd dawl fiz zmien l ohrajn kien kwazi jinqata kul gimgha u hadd ma kien jghid xejn",
#  'Ma mortx int expert ha jlestu f nofs il hin.....',
#  'Julia Cassar donnok bid deni',
#  'Jesmond Burduni meta naqra kumment bhal tieghek d deni donnu jizdied b mod super magel!!!!!',
#  '!',
#  'Julia Cassar indunajt',
#  'gws',
#  'Gws',
#  'AWGURI!',
#  '!',
#  'Awguri',
#  'Awguri',
#  'Congratulations',
#  'Awguri god bless you both',
#  'Auguri god bless xx',
#  'Awguri god bless',
#  'Both of you',
#  'Awguri ',
#  'Happy birthday to both',
#  'Awguri',
#  'Awguri',
#  'Happy birthday both god bless',
#  'Happy birthday both',
#  'Happy   birthday to you and dad xxxxxx',
#  'Awguri',
#  'Rest in peace',
#  'RIp',
#  'Rest in peace kugin',
#  'R.i.p Darren ',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Happy birthday',
#  'Awguri to you and your dad',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'AWGURI',
#  'Awguri',
#  'Awguri',
#  'Awguri',
#  'Awquri',
#  'Awguri',
#  'Happy Birthday',
#  'qalulla biex tmur id depo ghaliex ma marritx qadet taghel il live issa trid laqa mal kummissarju',
#  'Ejja tajjeb jekk xi hadd ha joqtlok jigi jghidlek ta lanqas dak li kun jilhaq iqer',
#  'Missa maret depot ma surgenta',
#  'Centre of attraction',
#  'Amanda Schembri',
#  'Michael Mizzi kemm ma nhobbix id drama hi  ..  tal hajja',
#  'Theddiet fuq hadd mhux tajjeb li jsir ghax xi hadd jasal biex iwettaq dak li heddek bik!',
#  'Qatt ma wiehed jaghzel li joqtol lil hadd…il-hajja hi don li taghna Alla, il-gisem hu misluf biex nihdu hsiebu sew mhux noqtluh u inkazbruh!',
#  'Naqsu li taghjru lil kulmin ikun please.',
#  'Erfa salibek ghax zgur hu tqil bizzejjed ghalik, terfax salib hadd iehor!',
#  'Ooo modonaa dejjem xi wahda gdida Al latenzjoni u leee lol',
#  'Ajma ...nahseb naqsulha l likes',
#  'Nispera li jtuk pulizija armati miek mhux ma jatux kaz',
#  'O madonna xwahda din  kuragg zija tt',
#  'Kif nistaw nemnuk jekk ma narawx nitfa Prova.🤣',
#  'Our Maltese Hollywood star ',
#  "Gwida hi...m'ghandkomx biex timlew jaqaw?",
#  'Mur ghand l bobby dak habib tijak',
#  'Riedu jghinuk u johduk id depot ghax ma mortx???',
#  'Paroli fil vojt kollok',
#  'Qeghdin toffru wisq gurnalizmu dilettantesk dwar persuni irrelevanti.',
#  'Mela l ewwel haga veru m ghandkomx biex timlew inthom tal gwida …  It tieni Zija Tt bniedem avzat nofsu armat … Anzi avzawk  U jekk bzajt daqshekk mhux kont tmur id depot !',
#  'The Celebrity of 2021    Ieqaf Dahhak in nies jahasra',
#  'Bhal ma ghajjart inti ter  l ommi majjartiex tebut go hanut nies kemm tiehdu f sormok ghax issib ic cwiec u ma jkelmuk xejn taaaa ghac li sibt lili ma kontx ha tghajjara',
#  'Lili kull darba li niggieldu jghidili ',
#  'Ara kif iridu nimlew il gurnalizmu u le le .. 1 st hadd ma jajdlek ha nigi noqtlok .. 2 nd qeda tofrilek li twaslek id depot hi ghax ma ghandix karozza .. u mur kull bassa li ikolok trid tamila live haluna nejxu',
#  "Iimmissek x hin offrewlek li jwaslek I'd depot imissek mort lilek x differenza kienet ser taghmillek xi kultant tkunu tridu il bajtra taqa f halqkom u kieku vera kont imwerwra nahseb il pass li kellek tiehu li tmur .Mela allura il gebla diga waqajta fuq saqajk hafna paroli zejda  ma jaghmel tajjeb ghal hadd imissek ghamilt kif qalulek.",
#  'Awguri',
#  'L mosta għaddejna minna l ġimgħa sa Sibt filgħodu.',
#  'Basta kienu wedu li ma jergax jinqata Gahan ta vera',
#  'Made In Malta Pajjiżż tat  Tielet Dinja min dak Hemm',
#  'Hawn il birgu ghadna bla dawl',
#  'Laqwa zmien gahan',
#  'Iva',
#  '€5000 X2 kuljum commision dik lis sarraf !!!',
#  'Plus li basta ngibu hafna barranin ara xgara issa were overloaded u mahniex preparati ghal dawn in nies kolla supply and demand kien qalilna u bid dranagg ifur gol bahar !!',
#  '!',
#  'Morru iccekkjaw it tanker tal gas tal gwida ha taraw?stupid question to ask......people are dying',
#  ...]

# %% [markdown]
# ## Removing comments which are not longer than 2 characters

# %%
for comment in cleaned_comments:
    if len(comment)<2:
        cleaned_comments.remove(comment)

# %%
len(cleaned_comments)
# Out:
# 114199

# %% [markdown]
# ## Checking for language of comments

# %% [markdown]
# As the library is not very accurate and most comments are either english or maltese, comments in english are removed but any comment classified as any other language is kept

# %%
final_comments = []
for comment in cleaned_comments:
    lang = langid.classify(comment)
    if lang[0] != 'en':
        final_comments.append(comment)

# %%
len(final_comments)  
with open('maltese_comments.csv', 'w', encoding='utf-8') as f:
    for item in final_comments:
        f.write("%s, " % item)

# %% [markdown]
# ## Open lists of Maltese words to compile our lexicon

# %%
data = []
for line in open('Resources/maltese_words.json', 'r',encoding='utf-8'):
    data.append(json.loads(line))
    
lexemes = []
for d in data:
    lemma = clean_word(d['lemma'])
    if len(lemma)>1:
        lexemes.append(lemma)
    if "alternatives" in d.keys():
        lexemes.append(d['alternatives'])

# %%
data = []
for line in open('Resources/other_maltese_words.json', 'r',encoding='utf-8'):
    data.append(json.loads(line))
    
for d in data:
    if "surface_form" in d:
        lexemes.append(d['surface_form'])
    if "plural_form" in d:
        lexemes.append(d['plural_form'])
    if "alternatives" in d:
        lexemes.append(d['alternatives'])

# %%
len(lexemes)
# Out:
# 4548284

# %%
maltese_words = []
for word in lexemes:
    if type(word) != str:
        maltese_words.extend(word)
    elif ' ' in word:
        words = tokenize(word)
        maltese_words.extend(words)
    else:
        maltese_words.append(word)

maltese_words = list(filter(lambda a: a != '', maltese_words))

# %%
len(maltese_words)
# Out:
# 4553264

# %%
special_characters = "_пc*"

final_words = []

for word in maltese_words:
    if not has_numbers(word) and not any(c in special_characters for c in word):
        final_words.append(word.lower())

# %%
dict_of_maltese_words = {}
for word in final_words:
    temp_list = []
    if word[0] in dict_of_maltese_words.keys():
        temp_list = dict_of_maltese_words[word[0]]
        temp_list.append(word)
        dict_of_maltese_words[word[0]] = temp_list
    else:
        temp_list.append(word)
        dict_of_maltese_words[word[0]] = temp_list

# %% [markdown]
# ## Check which words are misspelled

# %%
incorrect_words = []

for sentence in final_comments:
    sent = tokenize(sentence)
    for word in sent:
        if not word.isdigit():
            word = clean_word(word)
            if not check_list(incorrect_words,word):
                if word[0] in dict_of_maltese_words.keys():
                    if not check_list(dict_of_maltese_words[word[0]],word):
                        incorrect_words.append(word)

# %%
incorrect_words

with open('incorrect_words.csv', 'w', encoding='utf-8') as f:
    for item in incorrect_words:
        f.write("%s, " % item)

# %%
len(incorrect_words)
# Out:
# 54465

# %%
to_sub = {}

for word in incorrect_words:
    r = requests.get(' https://mlrs.research.um.edu.mt/resources/gabra-api/lexemes/search_suggest?s='+word)
    if(r.json()['results']):
        result = r.json()['results'][0]['lexeme']['lemma']
        to_sub[word] = result
        incorrect_words.remove(word)

# %%
to_sub
# Out:
# {'ezempju': 'eżempju',
#  'hegga': 'ħeġġa',
#  'kulhadd': 'kulħadd',
#  'mieghek': 'miegħek',
#  'genn': 'ġenn',
#  'hidma': 'ħidma',
#  'taghna': 'tagħna',
#  'ha': 'ħa',
#  'zgur': 'żgur',
#  'ghax': 'għax',
#  'ahna': 'aħna',
#  'genituri': 'ġenituri',
#  'pacenzja': 'paċenzja',
#  'ghajnuna': 'għajnuna',
#  'hadd': 'ħadd',
#  'maggoranza': 'maġġoranza',
#  'habba': 'ħabba',
#  'messagg': 'messaġġ',
#  'hin': 'ħin',
#  'imbaghad': 'imbagħad',
#  'herqa': 'ħerqa',
#  'mizura': 'miżura',
#  'gdid': 'ġdid',
#  'hazin': 'ħażin',
#  'hat': 'ħat',
#  'pjacir': 'pjaċir',
#  'sbieh': 'sbieħ',
#  'xoghol': 'xogħol',
#  'ghalxejn': 'għalxejn',
#  'abbuz': 'abbuż',
#  'strieh': 'straħ',
#  'naha': 'naħa',
#  'gmiel': 'ġmiel',
#  'gurnata': 'ġurnata',
#  'wicc': 'wiċċ',
#  'taghmil': 'tagħmil',
#  'ghala': 'għala',
#  'hlief': 'ħlief',
#  'gid': 'ġid',
#  'haga': 'ħaġa',
#  'dahk': 'daħk',
#  'pajjiz': 'pajjiż',
#  'fiducja': 'fiduċja',
#  'bzonn': 'bżonn',
#  'ghagla': 'għaġla',
#  'ghalik': 'għalik',
#  'medicina': 'mediċina',
#  'wiehed': 'wieħed',
#  'hara': 'ħara',
#  'doza': 'doża',
#  'tlugh': 'tligħ',
#  'ghan': 'għan',
#  'zejjed': 'żejjed',
#  'ahhar': 'aħħar',
#  'bhal': 'bħal',
#  'fragli': 'fraġli',
#  'certifikat': 'ċertifikat',
#  'zewg': 'żewġ',
#  'bizzejjed': 'biżżejjed',
#  'tuzzana': 'tużżana',
#  'ga': 'ġa',
#  'izjed': 'iżjed',
#  'izda': 'iżda',
#  'tahwid': 'taħwid',
#  'ghalfejn': 'għalfejn',
#  'ghamel': 'għamel',
#  'ghalhekk': 'għalhekk',
#  'hlif': 'ħlif',
#  'ezatt': 'eżatt',
#  'hniena': 'ħniena',
#  'skuza': 'skuża',
#  'qieghed': 'qiegħed',
#  'zibel': 'żibel',
#  'ghadira': 'għadira',
#  'zghar': 'żgħar',
#  'gili': 'ġili',
#  'cuc': 'ċuċ',
#  'helu': 'ħelu',
#  'ragel': 'raġel',
#  'gurnalizmu': 'ġurnaliżmu',
#  'kugin': 'kuġin',
#  'paci': 'paċi',
#  'shun': 'sħun',
#  'silg': 'silġ',
#  'gharef': 'għaref',
#  'cans': 'ċans',
#  'shana': 'sħana',
#  'hsara': 'ħsara',
#  'nuccali': 'nuċċali',
#  'ghat': 'għat',
#  'cucata': 'ċuċata',
#  'habta': 'ħabta',
#  'gie': 'ġie',
#  'telgha': 'telgħa',
#  'gieli': 'ġieli',
#  'zdied': 'żdied',
#  'addocc': 'addoċċ',
#  'difficli': 'diffiċli',
#  'zvilupp': 'żvilupp',
#  'specjalment': 'speċjalment',
#  'bhalissa': 'bħalissa',
#  'zahra': 'żahra',
#  'tbazwir': 'tbażwir',
#  'hela': 'ħela',
#  'licenzja': 'liċenzja',
#  'habs': 'ħabs',
#  'dahal': 'daħal',
#  'ghadu': 'għadu',
#  'hdax': 'ħdax',
#  'gimgha': 'ġimgħa',
#  'xhin': 'xħin',
#  'spicca': 'spiċċa',
#  'filghodu': 'filgħodu',
#  'jigifieri': 'jiġifieri',
#  'raguni': 'raġuni',
#  'pastazata': 'pastażata',
#  'zabbar': 'żabbar',
#  'aghar': 'agħar',
#  'gonta': 'ġonta',
#  'kcina': 'kċina',
#  'wieghed': 'wiegħed',
#  'ghageb': 'għaġeb',
#  'hajja': 'ħajja',
#  'gisem': 'ġisem',
#  'kuragg': 'kuraġġ',
#  'hanut': 'ħanut',
#  'vultagg': 'vultaġġ',
#  'fazi': 'fażi',
#  'shih': 'sħiħ',
#  'cajt': 'ċajt',
#  'suggeriment': 'suġġeriment',
#  'hali': 'ħali',
#  'thallas': 'tħallas',
#  'zball': 'żball',
#  'egoizmu': 'egoiżmu',
#  'gbira': 'ġbira',
#  'generalment': 'ġeneralment',
#  'ghasel': 'għasel',
#  'nhall': 'nħall',
#  'guh': 'ġuħ',
#  'zejjet': 'żejjet',
#  'dizastru': 'diżastru',
#  'minhabba': 'minħabba',
#  'hmistax': 'ħmistax',
#  'rahal': 'raħal',
#  'centru': 'ċentru',
#  'specjali': 'speċjali',
#  'taht': 'taħt',
#  'xaghar': 'xagħar',
#  'vergni': 'verġni',
#  'tieg': 'tieġ',
#  'pellegrinagg': 'pellegrinaġġ',
#  'holqien': 'ħolqien',
#  'hruq': 'ħruq',
#  'zghir': 'żgħir',
#  'semplici': 'sempliċi',
#  'gewwa': 'ġewwa',
#  'guf': 'ġuf',
#  'mohh': 'moħħ',
#  'kapaci': 'kapaċi',
#  'gurnalist': 'ġurnalist',
#  'hadra': 'ħadra',
#  'herba': 'ħerba',
#  'ruh': 'ruħ',
#  'hasra': 'ħasra',
#  'haqq': 'ħaqq',
#  'gharaq': 'għaraq',
#  'habi': 'ħabi',
#  'qahba': 'qaħba',
#  'ghaxija': 'għaxija',
#  'stahba': 'staħba',
#  'hatt': 'ħatt',
#  'loghba': 'logħba',
#  'cara': 'ċara',
#  'ghid': 'għid',
#  'ferriehi': 'ferrieħi',
#  'progett': 'proġett',
#  'mohqrija': 'moħqrija',
#  'hmieg': 'ħmieġ',
#  'innocenti': 'innoċenti',
#  'cella': 'ċella',
#  'hames': 'ħames',
#  'hobz': 'ħobż',
#  'lehen': 'leħen',
#  'kuncert': 'kunċert',
#  'thajjar': 'tħajjar',
#  'hares': 'ħares',
#  'ahmar': 'aħmar',
#  'zieda': 'żieda',
#  'logiku': 'loġiku',
#  'serrah': 'serraħ',
#  'tghaddas': 'tgħaddas',
#  'gbin': 'ġbin',
#  'turizmu': 'turiżmu',
#  'tghin': 'tgħin',
#  'ghalkemm': 'għalkemm',
#  'duhhan': 'duħħan',
#  'fizika': 'fiżika',
#  'tezor': 'teżor',
#  'lehja': 'leħja',
#  'harba': 'ħarba',
#  'halq': 'ħalq',
#  'zigg': 'żigg',
#  'regina': 'reġina',
#  'gojjell': 'ġojjell',
#  'piz': 'piż',
#  'speci': 'speċi',
#  'gilda': 'ġilda',
#  'ghasra': 'għasra',
#  'ghodwa': 'għodwa',
#  'gharrieda': 'għarrieda',
#  'boghod': 'bogħod',
#  'irranga': 'irranġa',
#  'hadem': 'ħadem',
#  'gustizzja': 'ġustizzja',
#  'curkett': 'ċurkett',
#  'zaqq': 'żaqq',
#  'zewgt': 'żewġ',
#  'allahares': 'allaħares',
#  'nghamel': 'ngħamel',
#  'decizjoni': 'deċiżjoni',
#  'xaghri': 'xagħri',
#  'fieh': 'fieħ',
#  'oht': 'oħt',
#  'tghajjar': 'tgħajjar',
#  'ghajjar': 'għajjar',
#  'tigiega': 'tiġieġa',
#  'vuci': 'vuċi',
#  'vicin': 'viċin',
#  'ghatba': 'għatba',
#  'ghazla': 'għażla',
#  'coff': 'ċoff',
#  'hewa': 'ħewa',
#  'prezzjuz': 'prezzjuż',
#  'verzjoni': 'verżjoni',
#  'ingliz': 'ingliż',
#  'muzika': 'mużika',
#  'ziffa': 'żiffa',
#  'ghazel': 'għażel',
#  'zibga': 'żibġa',
#  'hdura': 'ħdura',
#  'ghira': 'għira',
#  'mistrieh': 'mistrieħ',
#  'ghodda': 'għodda',
#  'gzira': 'gżira',
#  'frazi': 'frażi',
#  'hanex': 'ħanex',
#  'minghajr': 'mingħajr',
#  'tragedja': 'traġedja',
#  'rebbieh': 'rebbieħ',
#  'prezenti': 'preżenti',
#  'intelligenti': 'intelliġenti',
#  'genju': 'ġenju',
#  'krucjali': 'kruċjali',
#  'success': 'suċċess',
#  'gurija': 'ġurija',
#  'ghaxra': 'għaxra',
#  'hanzir': 'ħanżir',
#  'gakketta': 'ġakketta',
#  'ghajn': 'għajn',
#  'thabbat': 'tħabbat',
#  'ragg': 'raġġ',
#  'poezija': 'poeżija',
#  'haxix': 'ħaxix',
#  'spinaci': 'spinaċi',
#  'ohxon': 'oħxon',
#  'materjalizmu': 'materjaliżmu',
#  'dhul': 'dħul',
#  'ghaqda': 'għaqda',
#  'zjara': 'żjara',
#  'hmar': 'ħmar',
#  'rah': 'raħ',
#  'gbejna': 'ġbejna',
#  'cavetta': 'ċavetta',
#  'origini': 'oriġini',
#  'qazquz': 'qażquż',
#  'laham': 'laħam',
#  'hasel': 'ħasel',
#  'riha': 'riħa',
#  'pastaz': 'pastaż',
#  'miftuh': 'miftuħ',
#  'hamrija': 'ħamrija',
#  'zobb': 'żobb',
#  'principali': 'prinċipali',
#  'spiza': 'spiża',
#  'spizjar': 'spiżjar',
#  'oppozizzjoni': 'oppożizzjoni',
#  'taghlim': 'tagħlim',
#  'zwieg': 'żwieġ',
#  'rizultat': 'riżultat',
#  'uzat': 'użat',
#  'frenza': 'frenża',
#  'borza': 'borża',
#  'nghas': 'ngħas',
#  'zarbun': 'żarbun',
#  'hallas': 'ħallas',
#  'ciniz': 'ċiniż',
#  'mhatra': 'mħatra',
#  'gurnal': 'ġurnal',
#  'originali': 'oriġinali',
#  'hoss': 'ħoss',
#  'zebbugi': 'żebbuġi',
#  'thallat': 'tħallat',
#  'zurrieqi': 'żurrieqi',
#  'zejtuni': 'żejtuni',
#  'bilanc': 'bilanċ',
#  'vazun': 'vażun',
#  'griz': 'griż',
#  'dghajsa': 'dgħajsa',
#  'siggu': 'siġġu',
#  'moghza': 'mogħża',
#  'zabbari': 'żabbari',
#  'tarag': 'taraġ',
#  'faccata': 'faċċata',
#  'catt': 'ċatt',
#  'habel': 'ħabel',
#  'wahdu': 'waħdu',
#  'azzmu': 'ażżmu',
#  'hiena': 'ħjiena',
#  'lingwagg': 'lingwaġġ',
#  'gejjieni': 'ġejjieni',
#  'ungeriz': 'ungeriż',
#  'gobon': 'ġobon',
#  'wahx': 'waħx',
#  'zviluppat': 'żviluppat',
#  'corma': 'ċorma',
#  'frigg': 'friġġ',
#  'zbir': 'żbir',
#  'rebbiegha': 'rebbiegħa',
#  'harifa': 'ħarifa',
#  'zerriegha': 'żerriegħa',
#  'gunju': 'ġunju',
#  'ghoxrin': 'għoxrin',
#  'principju': 'prinċipju',
#  'sbuhija': 'sbuħa',
#  'hanin': 'ħanin',
#  'wicca': 'wiċċa',
#  'ghajxien': 'għajxien',
#  'sahansitra': 'saħansitra',
#  'giza': 'ġiża',
#  'wiegeb': 'wieġeb',
#  'hila': 'ħila',
#  'esagerat': 'esaġerat',
#  'rahhal': 'raħħal',
#  'qziez': 'qżież',
#  'shaba': 'sħaba',
#  'genwin': 'ġenwin',
#  'melha': 'melħa',
#  'zbaljat': 'żbaljat',
#  'ferh': 'ferħ',
#  'hdejn': 'ħdejn',
#  'ghoxx': 'għoxx',
#  'sorpriza': 'sorpriża',
#  'buzzieqa': 'bużżieqa',
#  'gabar': 'ġabar',
#  'mixhut': 'mixħut',
#  'incident': 'inċident',
#  'ezami': 'eżami',
#  'zikk': 'żigg',
#  'ddahhal': 'ddaħħal',
#  'capcap': 'ċapċap',
#  'han': 'ħan',
#  'uzu': 'użu',
#  'mewg': 'mewġ',
#  'gholi': 'għoli',
#  'żghir': 'żgħir',
#  'hawwel': 'ħawwel',
#  'socjali': 'soċjali',
#  'hazen': 'ħażen',
#  'tbiha': 'tbiħa',
#  'kuccarina': 'kuċċarina',
#  'tahra': 'taħra',
#  'siegha': 'siegħa',
#  'filghaxija': 'filgħaxija',
#  'gebel': 'ġebel',
#  'ezattament': 'eżattament',
#  'guri': 'ġuri',
#  'plegg': 'pleġġ',
#  'razan': 'rażan',
#  'haddiem': 'ħaddiem',
#  'biezel': 'bieżel',
#  'urgenti': 'urġenti',
#  'poggut': 'poġġut',
#  'hjata': 'ħjata',
#  'generali': 'ġenerali',
#  'ghoqda': 'għoqda',
#  'hadid': 'ħadid',
#  'socjalizmu': 'soċjaliżmu',
#  'ghazzien': 'għażżien',
#  'htija': 'ħtija',
#  'ghadda': 'għadda',
#  'laghaqi': 'lagħaqi',
#  'feroci': 'feroċi',
#  'cinga': 'ċinga',
#  'gnien': 'ġnien',
#  'haseb': 'ħaseb',
#  'egizzjan': 'eġizzjan',
#  'mahha': 'maħħa',
#  'haj': 'ħaj',
#  'bzieq': 'bżieq',
#  'uza': 'uża',
#  'fetah': 'fetaħ',
#  'treghid': 'tregħid',
#  'hamsa': 'ħamsa',
#  'gibed': 'ġibed',
#  'harga': 'ħarġa',
#  'nizla': 'niżla',
#  'fahhar': 'faħħar',
#  'xghar': 'xgħar',
#  'gera': 'ġera',
#  'hass': 'ħass',
#  'sehh': 'seħħ',
#  'ingenerali': 'inġenerali',
#  'twahhal': 'twaħħal',
#  'ghassa': 'għassa',
#  'avviz': 'avviż',
#  'passiggier': 'passiġġier',
#  'tqabbez': 'tqabbeż',
#  'hofra': 'ħofra',
#  'dahna': 'daħna',
#  'hamiem': 'ħamiem',
#  'kontracettiv': 'kontraċettiv',
#  'ahdar': 'aħdar',
#  'selvagg': 'salvaġġ',
#  'hgieg': 'ħġieġ',
#  'hammiem': 'ħammiem',
#  'suggett': 'suġġett',
#  'gharukaza': 'għarukaża',
#  'hajra': 'ħajra',
#  'tlahhaq': 'tlaħħaq',
#  'specjalizzat': 'speċjalizzat',
#  'abbuza': 'abbuża',
#  'thares': 'tħares',
#  'mizbla': 'miżbla',
#  'generazzjoni': 'ġenerazzjoni',
#  'zejza': 'żejża',
#  'deciz': 'deċiż',
#  'bzar': 'bżar',
#  'carta': 'ċarta',
#  'tagen': 'taġen',
#  'ghana': 'għana',
#  'taghlima': 'tagħlima',
#  'zar': 'żar',
#  'ghafas': 'għafas',
#  'haba': 'ħaba',
#  'specifikament': 'speċifikament',
#  'stenbah': 'stenbaħ',
#  'gagga': 'gaġġa',
#  'gholla': 'għolla',
#  'heles': 'ħeles',
#  'cumnija': 'ċumnija',
#  'wiesgha': 'wiesgħa',
#  'agenzija': 'aġenzija',
#  'holm': 'ħolm',
#  'thaffer': 'tħaffer',
#  'thaffir': 'tħaffir',
#  'holom': 'ħolom',
#  'pozizzjoni': 'pożizzjoni',
#  'sahan': 'saħan',
#  'hmerija': 'ħmerija',
#  'hawwad': 'ħawwad',
#  'hafer': 'ħafer',
#  'gbir': 'ġbir',
#  'kiesah': 'kiesaħ',
#  'hamallata': 'ħamallata',
#  'kaccatur': 'kaċċatur',
#  'handaq': 'ħandaq',
#  'sempliciment': 'sempliċiment',
#  'arcisqof': 'arċisqof',
#  'mignun': 'miġnun',
#  'fwieha': 'fwieħa',
#  'difiza': 'difiża',
#  'zipp': 'żipp',
#  'żewg': 'żewġ',
#  'merhla': 'merħla',
#  'saha': 'saħa',
#  'kacca': 'kaċċa',
#  'ghasfur': 'għasfur',
#  'inkluz': 'inkluż',
#  'zebra': 'żebra',
#  'ghamla': 'għamla',
#  'hill': 'ħall',
#  'harab': 'ħarab',
#  'agenda': 'aġenda',
#  'ghaks': 'għaks',
#  'herqan': 'ħerqan',
#  'cekk': 'ċekk',
#  'mhallef': 'mħallef',
#  'mustaccun': 'mustaċċun',
#  'hlas': 'ħlas',
#  'xahat': 'xaħat',
#  'helsien': 'ħelsien',
#  'cicra': 'ċiċra',
#  'imzewwaq': 'imżewwaq',
#  'hallata': 'ħallata',
#  'mehtieg': 'meħtieġ',
#  'ufficcju': 'uffiċċju',
#  'mahmug': 'maħmuġ',
#  'harra': 'ħarra',
#  'genb': 'ġenb',
#  'tixjih': 'tixjiħ',
#  'camata': 'ċamata',
#  'nehha': 'neħħa',
#  'seher': 'seħer',
#  'ghatx': 'għatx',
#  'cinturin': 'ċinturin',
#  'nbiegh': 'nbiegħ',
#  'bejgh': 'bejgħ',
#  'tbigh': 'tbigħ',
#  'analizi': 'analiżi',
#  'teknologija': 'teknoloġija',
#  'ftahar': 'ftaħar',
#  'gibjun': 'ġibjun',
#  'favoritizmu': 'favoritiżmu',
#  'bahh': 'baħħ',
#  'emergenza': 'emerġenza',
#  'tpacpic': 'tpaċpiċ',
#  'halliel': 'ħalliel',
#  'eccellenti': 'eċċellenti',
#  'ricerka': 'riċerka',
#  'ircevuta': 'riċevuta',
#  'mhabba': 'mħabba',
#  'hlejqa': 'ħlejqa',
#  'hażin': 'ħażin',
#  'migbud': 'miġbud',
#  'gustuz': 'gustuż',
#  'dicembru': 'diċembru',
#  'hell': 'ħall',
#  'nfetah': 'nfetaħ',
#  'hamallu': 'ħamallu',
#  'wehel': 'weħel',
#  'habbar': 'ħabbar',
#  'specjalista': 'speċjalista',
#  'appogg': 'appoġġ',
#  'ftuh': 'ftuħ',
#  'decenti': 'deċenti',
#  'perkacci': 'perkaċċi',
#  'horn': 'ħorn',
#  'cilindru': 'ċilindru',
#  'bahnan': 'baħnan',
#  'kazin': 'każin',
#  'ugigh': 'uġigħ',
#  'prezenza': 'preżenza',
#  'ghama': 'għama',
#  'loghob': 'logħob',
#  'zrar': 'żrar',
#  'gieb': 'ġab',
#  'fazola': 'fażola',
#  'imbecilli': 'imbeċilli',
#  'registrat': 'reġistrat',
#  'tisbih': 'tisbiħ',
#  'toghma': 'togħma',
#  'facilment': 'faċilment',
#  'qiegh': 'qiegħ',
#  'mincott': 'minċott',
#  'glied': 'ġlied',
#  'dizunur': 'diżunur',
#  'mahbub': 'maħbub',
#  'iddispjacih': 'iddispjaċih',
#  'hlejjaq': 'ħlejjaq',
#  'zaqqa': 'żaqqa',
#  'carruta': 'ċarruta',
#  'haġa': 'ħaġa',
#  'kummerc': 'kummerċ',
#  'dezerta': 'deżerta',
#  'thaddem': 'tħaddem',
#  'raghaj': 'ragħaj',
#  'shit': 'sħit',
#  'zring': 'żrinġ',
#  'hazna': 'ħażna',
#  'helles': 'ħelles',
#  'melh': 'melħ',
#  'pjanca': 'pjanċa',
#  'mgarr': 'mġarr',
#  'hotba': 'ħotba',
#  'zebgha': 'żebgħa',
#  'moqziez': 'moqżież',
#  'lewz': 'lewż',
#  'sponza': 'sponża',
#  'nghazel': 'ngħażel',
#  'gibs': 'ġibs',
#  'indahal': 'indaħal',
#  'henn': 'ħenn',
#  'gharbi': 'għarbi',
#  'cimiterju': 'ċimiterju',
#  'ghadma': 'għadma',
#  'fiziku': 'fiżiku',
#  'priza': 'priża',
#  'lahaq': 'laħaq',
#  'cangatura': 'ċangatura',
#  'ghajjat': 'għajjat',
#  'nghalaq': 'ngħalaq',
#  'qabez': 'qabeż',
#  'hsib': 'ħsib',
#  'geru': 'ġeru',
#  'beccun': 'beċċun',
#  'biccerija': 'biċċerija',
#  'roza': 'roża',
#  'gharfien': 'għarfien',
#  'tnehhija': 'tneħħija',
#  'dezert': 'deżert',
#  'ikkawzat': 'ikkawżat',
#  'hann': 'ħenn',
#  'hieles': 'ħieles',
#  'zbilanc': 'żbilanċ',
#  'froga': 'froġa',
#  'thawwad': 'tħawwad',
#  'magistrat': 'maġistrat',
#  'tigrija': 'tiġrija',
#  'rewwah': 'rewwaħ',
#  'energija': 'enerġija',
#  'certezza': 'ċertezza',
#  'berah': 'beraħ',
#  'naghga': 'nagħġa',
#  'zied': 'żied',
#  'cint': 'ċint',
#  'mithna': 'mitħna',
#  'zdingat': 'żdingat',
#  'halaq': 'ħalaq',
#  'cirku': 'ċirku',
#  'sebah': 'sebaħ',
#  'hfief': 'ħfief',
#  'incirata': 'inċirata',
#  'tixhim': 'tixħim',
#  'haffer': 'ħaffer',
#  'pozittiv': 'pożittiv',
#  'ndahal': 'ndaħal',
#  'glekk': 'ġlekk',
#  'zarma': 'żarma',
#  'oggett': 'oġġett',
#  'qabza': 'qabża',
#  'ricetta': 'riċetta',
#  'hagar': 'ħaġar',
#  'qtugh': 'qtigħ',
#  'tkessah': 'tkessaħ',
#  'gelat': 'ġelat',
#  'ghalf': 'għalf',
#  'salvagg': 'salvaġġ',
#  'artificjali': 'artifiċjali',
#  'ghallem': 'għallem',
#  'hajjet': 'ħajjet',
#  'digitali': 'diġitali',
#  'cerva': 'ċerva',
#  'gidri': 'ġidri',
#  'targa': 'tarġa',
#  'tpingija': 'tpinġija',
#  'gieh': 'ġieħ',
#  'ftahir': 'ftaħir',
#  'ghoti': 'għoti',
#  'hambaq': 'ħambaq',
#  'ttiehed': 'ttieħed',
#  'ghen': 'għen',
#  'twahhil': 'twaħħil',
#  'hnizrija': 'ħniżrija',
#  'magenb': 'maġenb',
#  'prezentatur': 'preżentatur',
#  'habbat': 'ħabbat',
#  'psikologija': 'psikoloġija',
#  'kagun': 'kaġun',
#  'tmecliq': 'tmeċliq',
#  'prigunerija': 'priġunerija',
#  'hata': 'ħata',
#  'qazzez': 'qażżeż',
#  'bezaq': 'beżaq',
#  'heffa': 'ħeffa',
#  'qligh': 'qligħ',
#  'zfin': 'żfin',
#  'fahxija': 'faħxija',
#  'dizgrazzja': 'diżgrazzja',
#  'bocca': 'boċċa',
#  'gharwien': 'għarwien',
#  'tbih': 'tbiħ',
#  'gharus': 'għarus',
#  'zamma': 'żamma',
#  'hater': 'ħater',
#  'alkohol': 'alkoħol',
#  'gwiez': 'ġwież',
#  'brungiel': 'brunġiel',
#  'pulcinell': 'pulċinell',
#  'ruzarju': 'rużarju',
#  'perikoluz': 'perikoluż',
#  'vjagg': 'vjaġġ',
#  'beneficcju': 'benefiċċju',
#  'zona': 'żona',
#  'tahna': 'taħna',
#  'religjon': 'reliġjon',
#  'ngibed': 'nġibed',
#  'tghaffas': 'tgħaffas',
#  'access': 'aċċess',
#  'sieheb': 'sieħeb',
#  'ggennen': 'ġġennen',
#  'bezqa': 'beżqa',
#  'hbiberija': 'ħbiberija',
#  'laghab': 'lagħab',
#  'ghaxqa': 'għaxqa',
#  'ghadba': 'għadba',
#  'hall': 'ħall',
#  'twegiba': 'tweġiba',
#  'weggha': 'waġgħa',
#  'hatu': 'ħatu',
#  'thaddan': 'tħaddan',
#  'gherf': 'għerf',
#  'mizbel': 'miżbla',
#  'dahhal': 'daħħal',
#  'okkazjoni': 'okkażjoni',
#  'zifna': 'żifna',
#  'azma': 'ażma',
#  'ghaziz': 'għażiż',
#  'hammeg': 'ħammeġ',
#  'zanzan': 'żanżan',
#  'pagna': 'paġna',
#  'tqazzez': 'tqażżeż',
#  'ezemplari': 'eżemplari',
#  'habb': 'ħabb',
#  'grada': 'ġrada',
#  'hrug': 'ħruġ',
#  'cawla': 'ċawla',
#  'zbalja': 'żbalja',
#  'tghajjir': 'tgħajjir',
#  'pecluq': 'peċluq',
#  'hasil': 'ħasil',
#  'tifhir': 'tifħir',
#  'wiggeb': 'wiġġeb',
#  'ilbierah': 'ilbieraħ',
#  'dahan': 'daħan',
#  'zabra': 'żabra',
#  'izzejjed': 'iżżejjed',
#  'oggezzjoni': 'oġġezzjoni',
#  'hamsin': 'ħamsin',
#  'fettah': 'fettaħ',
#  'harir': 'ħarir',
#  'hrafa': 'ħrafa',
#  'dahhaq': 'daħħak',
#  'hoxna': 'ħoxna',
#  'hallieq': 'ħallieq',
#  'cafcaf': 'ċafċaf',
#  'thalla': 'tħalla',
#  'mcaqlaq': 'mċaqlaq',
#  'ghatu': 'għatu',
#  'cerna': 'ċerna',
#  'tghaqqid': 'għaqid',
#  'hama': 'ħama',
#  'gurdien': 'ġurdien',
#  'process': 'proċess',
#  'haddem': 'ħaddem',
#  'sebgha': 'sebgħa',
#  'faham': 'faħam',
#  'suwicidju': 'suwiċidju',
#  'divizjoni': 'diviżjoni',
#  'zatat': 'żatat',
#  'rebha': 'rebħa',
#  'hafa': 'ħafa',
#  'ccaqlaq': 'ċċaqlaq',
#  'gemgha': 'ġemgħa',
#  'ezilju': 'eżilju',
#  'cikkulata': 'ċikkulata',
#  'bezzul': 'beżżul',
#  'belgha': 'belgħa',
#  'bizel': 'biżel',
#  'vagina': 'vaġina',
#  'dranagg': 'dranaġġ',
#  'habat': 'ħabat',
#  'iggudika': 'iġġudika',
#  'raghad': 'ragħad',
#  'ghawm': 'għawm',
#  'gaza': 'gaża',
#  'rapprezentant': 'rappreżentant',
#  'maghmul': 'magħmul',
#  'mirakoluz': 'mirakoluż',
#  'zbih': 'żbigħ',
#  'kabocca': 'kaboċċa',
#  'nahla': 'naħla',
#  'dagha': 'dagħa',
#  'zaghzugh': 'żagħżugħ',
#  'sahna': 'saħna',
#  'bhar': 'bħur',
#  'sehet': 'seħet',
#  'nharaq': 'nħaraq',
#  'tnehha': 'tneħħa',
#  'nahha': 'neħħa',
#  'hexa': 'ħexa',
#  'gerzuma': 'gerżuma',
#  'xemgha': 'xemgħa',
#  'velenuz': 'velenuż',
#  'trangat': 'tranġat',
#  'haf': 'ħaf',
#  'habsi': 'ħabsi',
#  'rieh': 'rieħ',
#  'gham': 'għam',
#  'cokon': 'ċokon',
#  'tbaghbas': 'tbagħbas',
#  'tpahpih': 'tpaħpiħ',
#  'biegh': 'biegħ',
#  'mghobbi': 'mgħobbi',
#  'dispjacir': 'dispjaċir',
#  'tingis': 'tinġis',
#  'mahkum': 'maħkum',
#  'comb': 'ċomb',
#  'ghejja': 'għejja',
#  'nahli': 'naħli',
#  'hati': 'ħati',
#  'twaqqigh': 'twaqqigħ',
#  'rebah': 'rebaħ',
#  'ghex': 'għex',
#  'grajja': 'ġrajja',
#  'percimes': 'perċimes',
#  'haraq': 'ħaraq',
#  'gidra': 'ġidra',
#  'fergha': 'fergħa',
#  'baghad': 'bagħad',
#  'franciz': 'franċiż',
#  'ufficjal': 'uffiċjal',
#  'moghdrija': 'mogħdrija',
#  'zebbuga': 'żebbuġa',
#  'hondoq': 'ħandaq',
#  'ricevuta': 'riċevuta',
#  'baghal': 'bagħal',
#  'twiegeb': 'twieġeb',
#  'trebbah': 'trebbaħ',
#  'civili': 'ċivili',
#  'gurament': 'ġurament',
#  'merhba': 'merħba',
#  'cappa': 'ċappa',
#  'studjuz': 'studjuż',
#  'ghali': 'għali',
#  'midhla': 'midħla',
#  'tniggis': 'tniġġis',
#  'gheneb': 'għeneb',
#  'baqgha': 'baqgħa',
#  'kancer': 'kanċer',
#  'tronga': 'tronġa',
#  'ufficjali': 'uffiċjali',
#  'tharrek': 'tħarrek',
#  'thassar': 'tħassar',
#  'bazikament': 'bażikament',
#  'eccessiv': 'eċċessiv',
#  'eccellenza': 'eċċellenza',
#  'qaccat': 'qaċċat',
#  'gieghel': 'ġiegħel',
#  'indicenti': 'indiċenti',
#  'hajm': 'ħajm',
#  'mghaggel': 'mgħaġġel',
#  'passiggata': 'passiġġata',
#  'ghadd': 'għadd',
#  'rebh': 'rebħ',
#  'vantagg': 'vantaġġ',
#  'tqarmec': 'tqarmeċ',
#  'zgura': 'żgura',
#  'ceda': 'ċeda',
#  'ikkaguna': 'ikkaġuna',
#  'rapprezentazzjoni': 'rappreżentazzjoni',
#  'kuncett': 'kunċett',
#  'imghax': 'imgħax',
#  'precedenti': 'preċedenti',
#  'hawt': 'ħawt',
#  'ghass': 'għass',
#  'bzonjuz': 'bżonjuż',
#  'cens': 'ċens',
#  'imnieher': 'mnieħer',
#  'ghalla': 'għalla',
#  'nicca': 'niċċa',
#  'dizordni': 'diżordni',
#  'mrewha': 'mrewħa',
#  'ghaqli': 'għaqli',
#  'efficjenti': 'effiċjenti',
#  'wizna': 'wiżna',
#  'peclaq': 'peċlaq',
#  'dmugh': 'dmugħ',
#  'cuplajs': 'ċuplajs',
#  'hjiel': 'ħjiel',
#  'gazaza': 'gażaża',
#  'raghwa': 'ragħwa',
#  'gelu': 'ġelu',
#  'gugarell': 'ġugarell',
#  'braziljan': 'brażiljan',
#  'pizella': 'piżella',
#  'hazzez': 'ħażżeż',
#  'famuz': 'famuż',
#  'tahlit': 'taħlit',
#  'incova': 'inċova',
#  'princep': 'prinċep',
#  'sehhet': 'seħħet',
#  'muzew': 'mużew',
#  'dahak': 'daħak',
#  'celebrazzjoni': 'ċelebrazzjoni',
#  'tabilhaqq': 'tabilħaqq',
#  'haxxej': 'ħaxxej',
#  'stagun': 'staġun',
#  'tizjin': 'tiżjin',
#  'ghati': 'għoti',
#  'canga': 'ċanga',
#  'nholoq': 'nħalaq',
#  'ghagina': 'għaġina',
#  'nhass': 'nħass',
#  'zibla': 'żibla',
#  'nizzel': 'niżżel',
#  'gemel': 'ġemel',
#  'bazi': 'bażi',
#  'thabbar': 'tħabbar',
#  'har': 'ħar',
#  'gennata': 'ġennata',
#  'caghaq': 'ċiegħek',
#  'hawsla': 'ħawsla',
#  'ħareg': 'ħareġ',
#  'akkuza': 'akkuża',
#  'tnizzel': 'tniżżel',
#  'ahrax': 'aħrax',
#  'masgar': 'masġar',
#  'hlit': 'ħalt',
#  'nizli': 'nżuli',
#  'mhallat': 'mħallat',
#  'bziequ': 'bżiequ',
#  'faqqiegh': 'faqqiegħ',
#  'gentili': 'ġentili',
#  'lanca': 'lanċa',
#  'hobla': 'ħobla',
#  'semgha': 'semgħa',
#  'gerra': 'ġerra',
#  'minacca': 'minaċċa',
#  'tqabez': 'tqabeż',
#  'baziku': 'bażiku',
#  'zjieda': 'żieda',
#  'baghat': 'bagħat',
#  'ghomor': 'għomor',
#  'pogga': 'poġġa',
#  'hlis': 'ħlis',
#  'mibeghda': 'mibegħda',
#  'magija': 'maġija',
#  'zlieq': 'żlieq',
#  'thammeg': 'tħammeġ',
#  'nahra': 'naħra',
#  'gifa': 'ġifa',
#  'intiz': 'intiż',
#  'rangat': 'ranġat',
#  'buzbiez': 'bużbież',
#  'wgigh': 'uġigħ',
#  'ccarrat': 'ċċarrat',
#  'mielah': 'mielaħ',
#  'cerimonja': 'ċerimonja',
#  'tqancic': 'tqanċiċ',
#  'racanc': 'raċanċ',
#  'hassel': 'ħassel',
#  'qamh': 'qamħ',
#  'kecca': 'keċċa',
#  'ghajb': 'għajb',
#  'qghad': 'qgħad',
#  'hien': 'ħan',
#  'iddecieda': 'iddeċieda',
#  'mohba': 'moħba',
#  'entuzjazmu': 'entużjażmu',
#  'olandiz': 'olandiż',
#  'mekkanizmu': 'mekkaniżmu',
#  'ksieh': 'ksieħ',
#  'tqanzih': 'tqanżiħ',
#  'sospiz': 'sospiż',
#  'thambiq': 'tħambiq',
#  'intelligenza': 'intelliġenza',
#  'registru': 'reġistru',
#  'cpar': 'ċpar',
#  'preciz': 'preċiż',
#  'invazjoni': 'invażjoni',
#  'zibeg': 'żibeġ',
#  'bahri': 'baħri',
#  'gawhra': 'ġawhra',
#  'bacir': 'baċir',
#  'mghallem': 'mgħallem',
#  'mizien': 'miżien',
#  'hagg': 'ħaġġ',
#  'gharqa': 'għarqa',
#  'koncernat': 'konċernat',
#  'gheja': 'għeja',
#  'ghads': 'għads',
#  'hageb': 'ħaġeb',
#  'mehriez': 'mehrież',
#  'hnejja': 'ħnejja',
#  'qaqocc': 'qaqoċċ',
#  'certament': 'ċertament',
#  'ghaldaqstant': 'għaldaqstant',
#  'sebghin': 'sebgħin',
#  'ħagar': 'ħaġar',
#  'ckejken': 'ċkejken',
#  'half': 'ħalf',
#  'ottimizmu': 'ottimiżmu',
#  'ghalabibizmu': 'għalabibiżmu',
#  'patrijottizmu': 'patrijottiżmu',
#  'gharghar': 'għargħar',
#  'gharbiel': 'għarbiel',
#  'irlandiz': 'irlandiż',
#  'soghla': 'sogħla',
#  'berga': 'berġa',
#  'ganc': 'ganċ',
#  'mahta': 'maħta',
#  'minfah': 'minfaħ',
#  'irrizenja': 'irriżenja',
#  'tpogga': 'tpoġġa',
#  'akkuzat': 'akkużat',
#  'gheluq': 'għeluq',
#  'hafi': 'ħafi',
#  'baghta': 'bagħta',
#  'staha': 'staħa',
#  ...}

# %%
len(incorrect_words)

# %%
def open_list(filename):
    with open(filename, "r", encoding='utf-8') as f:
        mylist = f.readlines()

    word_list = []
    for line in mylist:
        if word_list:
            word_list.extend(line.split(", "))
        else:
            word_list = line.split(", ")

    return word_list

# %%
maltese_words = open_list('CSV_files/maltese_words.txt')
print(len(maltese_words))
# Out:
# 4552977

# %%
#https://blog.paperspace.com/implementing-levenshtein-distance-word-autocomplete-autocorrect/
def get_words(word,dataset):
    list_of_dist = {}
    
    for data in dataset: 
        dist = distance(data, word)
        if dist < 3:
            list_of_dist[data] = dist

    dict(sorted(list_of_dist.items(), key=lambda item: item[1]))
    #print(len(list_of_dist))
    
    
    return list_of_dist

# %%
list_of_dist = get_words('ghax',maltese_words)
list_of_dist
# Out:
# {'ħrax': 2,
#  'għad': 2,
#  'għat': 2,
#  'għex': 2,
#  'għam': 2,
#  'grix': 2,
#  'gżar': 2,
#  'għaxq': 2,
#  'għaxi': 2,
#  'għan': 2,
#  'għar': 2,
#  'grad': 2,
#  'mhux': 2,
#  'ħdax': 2,
#  'għax': 1,
#  'għal': 2,
#  'għatx': 2,
#  'tnax': 2,
#  'gwaj': 2,
#  'grat': 2,
#  'gahan': 2,
#  'ghada': 2,
#  'than': 2,
#  'ghaba': 2,
#  'tham': 2,
#  'gwan': 2,
#  'ghabex': 2,
#  'nhar': 2,
#  'hux': 2,
#  'ghain': 2,
#  'ghij': 2,
#  'mgħax': 2,
#  'ghar': 1,
#  'tax': 2,
#  'gћan': 2,
#  'haxi': 2,
#  'that': 2,
#  'gżat': 2,
#  'gżaw': 2,
#  'gażax': 2,
#  'gżatx': 2,
#  'gżawx': 2,
#  'wżax': 2,
#  'għadx': 2,
#  'għix': 2,
#  'għamx': 2,
#  'għarx': 2,
#  'użax': 2,
#  'nqax': 2,
#  'gnaċ': 2}

# %% [markdown]
# ## Substituting every occurence of the incorrect word with the correct one

# %%
common_misspelled = {
    "tiegħi" : "tijaj"
    "għax" : "ax"
    "jj" : "jekk jogħġbok"
    "andi" : "għandi"
    "tiegħi" : "tijaj"

}


string_a = re.sub(r'(cat|dog)', 'pet', "Mark owns a dog and Mary owns a cat.")

#https://stackabuse.com/replace-occurrences-of-a-substring-in-string-with-python/
